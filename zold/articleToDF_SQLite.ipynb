# %%
import sqlite3
import datetime as datetime
conn = sqlite3.connect("testDB.db")

# %%
cur = conn.cursor()

# %%
import os
import itertools
import numpy as np
import pandas as pd
import xml.etree.ElementTree as ET
path = 'C:/Users/Pragati Shah/subset/'

# %%
#This function takes a directory path, parses all the xml files present in the directory, and returns the key attributes in
#the format of a dataframe.


import os
def articleToDF(path):
    mainDF=pd.DataFrame(columns=["doi","pmid","journal","publisher_id","publisher_name","authors","editors","subjects","title","alt_title","date_pub","date_rec","abstract","body"])
    tempDF=pd.DataFrame()
    for fn in os.listdir(path):
        author_surnames=[]
        author_names=[]
        editor_surnames=[]
        editor_names=[]
        subjects=[]
        title=[]
        alt_title=[]
        authors=[]
        editors=[]
        abstract=" "
        body=" "
        journal=" "
        publisher_id=" "
        publisher_name=" "
        rday=0
        rmonth=0
        ryear=0
        pday=0
        pmonth=0
        pyear=0
        tree = ET.parse(path+fn)  
        root = tree.getroot() 
        for elem in tree.iter(tag='article-id'):
            a=str(elem.attrib)
            if (a.find('pmid')>-1):        
                pmid=elem.text
            if (a.find('doi')>-1):        
                doi=elem.text
        for elem in tree.iter(tag='contrib'):
            a=str(elem.attrib)
            if (a.find('author')>-1):
                for i in elem.iter(tag='surname'):
                    #print (i.tag, i.attrib,i.text)
                    author_surnames.append(i.text)
                for i in elem.iter(tag='given-names'):
                    #print (i.tag, i.attrib,i.text)
                    author_names.append(i.text)
            spaces=' '* len(author_names)
            authors=list(map(operator.add,list(map(operator.add, author_names,spaces)), author_surnames))
            if (a.find('editor')>-1):
                for i in elem.iter(tag='surname'):
                    #print (i.tag, i.attrib,i.text)
                    editor_surnames.append(i.text)
                for i in elem.iter(tag='given-names'):
                    #print (i.tag, i.attrib,i.text)
                    editor_names.append(i.text)
            spaces=' '* len(editor_names)
            editors=list(map(operator.add,list(map(operator.add, editor_names,spaces)), editor_surnames))
                    
        for a in root.iter('article-meta'):
            for elem in a.iter('article-title'):
                title.append(elem.text)
            for elem in a.iter('alt-title'):
                alt_title.append(elem.text)
            for elem in a.iter('abstract'):    
                b=ET.tostring(elem, method='text', encoding='unicode')
                abstract=b
         
        for subject in root.iter('subject'):
            subjects.append(subject.text)
            
        for a in root.iter('pub-date'):
            for elem in a.iter('day'):
                pday=elem.text
            for elem in a.iter('month'):
                pmonth=elem.text
            for elem in a.iter('year'):
                #print(elem.text)
                pyear=elem.text
        str_pdate=str(pyear)+'-'+str(pmonth)+'-'+str(pday)
        date_pub=datetime.datetime.strptime(str_pdate, "%Y-%m-%d")

        for a in root.iter('date'):
            x=str(a.attrib)
            #print(a.find('author'))
            if (x.find('received')>-1):
                for elem in a.iter(tag='day'):
                    rday=elem.text
                for elem in a.iter(tag='month'):
                    rmonth=elem.text
                for elem in a.iter(tag='year'):
                    #print(elem.text)
                    ryear=elem.text
        str_rdate=str(ryear)+'-'+str(rmonth)+'-'+str(rday)
        date_rec=datetime.datetime.strptime(str_rdate, "%Y-%m-%d")
        
        for a in root.iter('body'):
            b=ET.tostring(a, method='text', encoding='unicode')
            body=b
        
        for elem in tree.iter(tag='journal-title'):
            journal=elem.text
            
        for elem in tree.iter(tag='journal-id'):
            a=str(elem.attrib)
            if (a.find('publisher-id')>-1):
                publisher_id=elem.text
             
        for elem in tree.iter(tag='journal-meta'):    
            for elem1 in elem.iter(tag='publisher-name'):    
                publisher_name=elem1.text

        mainDF.loc[len(mainDF)]=[doi,pmid,journal,publisher_id,publisher_name,authors,editors,subjects,title,alt_title,date_pub,date_rec,abstract,body]
    return(mainDF)

# %%
DF=articleToDF(path)
DF.head()
# Out:
#                             doi      pmid   journal publisher_id  \
# 0  10.1371/journal.pone.0000100  17183633  PLoS ONE         plos
# 1  10.1371/journal.pone.0000008  17183712  PLoS ONE         plos
# 2  10.1371/journal.pone.0000061  17183692  PLoS ONE         plos
# 3  10.1371/journal.pone.0000094  17183726  PLoS ONE         plos
# 4  10.1371/journal.pone.0000011  17183637  PLoS ONE         plos
#
#               publisher_name  \
# 0  Public Library of Science
# 1  Public Library of Science
# 2  Public Library of Science
# 3  Public Library of Science
# 4  Public Library of Science
#
#                                              authors                editors  \
# 0  [Justin A. Harris, Ehsan Arabzadeh, Adrienne L...  [Hernan Lopez-Schier]
# 1             [Maxim V. Kapralov, Dmitry A. Filatov]     [Konrad Scheffler]
# 2       [Andrey Rzhetsky, Tian Zheng, Chani Weinreb]            [Nick Monk]
# 3  [Jingchun Zhu, Ashwini Jambhekar, Aaron Sarver...  [Gustavo Stolovitzky]
# 4  [Matthew E. Falagas, Konstantinos N. Fragoulis...       [Bernhard Baune]
#
#                                             subjects  \
# 0   [Research Article, Neuroscience/Sensory Systems]
# 1           [Research Article, Evolutionary Biology]
# 2  [Research Article, Cell Biology, Computational...
# 3  [Research Article, Genetics and Genomics/Funct...
# 4  [Research Article, Public Health and Epidemiol...
#
#                                                title  \
# 0  [Factors Affecting Frequency Discrimination of...
# 1  [Molecular Adaptation during Adaptive Radiatio...
# 2       [Self-Correcting Maps of Molecular Pathways]
# 3  [A Bayesian Network Driven Approach to Model t...
# 4  [A Comparative Study on the Cost of New Antibi...
#
#                          alt_title   date_pub   date_rec  \
# 0    [Vibrotactile Discrimination] 2006-12-20 2006-10-19
# 1                           [None] 2006-12-20 2006-08-07
# 2       [Self-Correcting Pathways] 2006-12-20 2006-09-15
# 3  [Nitric Oxide Response Network] 2006-12-20 2006-09-16
# 4              [Cost of New Drugs] 2006-12-20 2006-08-28
#
#                                             abstract  \
# 0  BackgroundMeasuring perceptual judgments about...
# 1  Background“Explosive” adaptive radiations on i...
# 2  Reliable and comprehensive maps of molecular p...
# 3  The transcriptional response to exogenously su...
# 4  BackgroundDrug treatment is becoming more expe...
#
#                                                 body
# 0  IntroductionMany investigations of sensory pro...
# 1  IntroductionThe most dramatic “bursts” of adap...
# 2  IntroductionScientific innovation often procee...
# 3  IntroductionNitric oxide (NO·) is a critical m...
# 4  IntroductionThe investment of societies around...

# %%
DF.dtypes
# Out:
# doi                       object
# pmid                      object
# journal                   object
# publisher_id              object
# publisher_name            object
# authors                   object
# editors                   object
# subjects                  object
# title                     object
# alt_title                 object
# date_pub          datetime64[ns]
# date_rec          datetime64[ns]
# abstract                  object
# body                      object
# dtype: object

# %%
cols=[i for i in DF.columns if i not in ["date_pub","date_rec"]]
for col in cols:
    DF[col]=DF[col].astype('str')

# %%
DF.dtypes
# Out:
# doi                       object
# pmid                      object
# journal                   object
# publisher_id              object
# publisher_name            object
# authors                   object
# editors                   object
# subjects                  object
# title                     object
# alt_title                 object
# date_pub          datetime64[ns]
# date_rec          datetime64[ns]
# abstract                  object
# body                      object
# dtype: object

# %%
DF.to_sql("trial1", conn, if_exists="replace")

# %%
pd.read_sql_query("select * from trial1;", conn)
# Out:
#     index                           doi      pmid   journal publisher_id  \
# 0       0  10.1371/journal.pone.0000100  17183633  PLoS ONE         plos
# 1       1  10.1371/journal.pone.0000008  17183712  PLoS ONE         plos
# 2       2  10.1371/journal.pone.0000061  17183692  PLoS ONE         plos
# 3       3  10.1371/journal.pone.0000094  17183726  PLoS ONE         plos
# 4       4  10.1371/journal.pone.0000011  17183637  PLoS ONE         plos
# 5       5  10.1371/journal.pone.0000131  17205135  PLoS ONE         plos
# 6       6  10.1371/journal.pone.0000077  17183709  PLoS ONE         plos
# 7       7  10.1371/journal.pone.0000027  17183654  PLoS ONE         plos
# 8       8  10.1371/journal.pone.0000080  17183713  PLoS ONE         plos
# 9       9  10.1371/journal.pone.0000102  17183635  PLoS ONE         plos
# 10     10  10.1371/journal.pone.0000030  17183658  PLoS ONE         plos
# 11     11  10.1371/journal.pone.0000063  17183694  PLoS ONE         plos
# 12     12  10.1371/journal.pone.0000096  17183728  PLoS ONE         plos
# 13     13  10.1371/journal.pone.0000013  17183639  PLoS ONE         plos
# 14     14  10.1371/journal.pone.0000046  17183675  PLoS ONE         plos
# 15     15  10.1371/journal.pone.0000079  17183711  PLoS ONE         plos
# 16     16  10.1371/journal.pone.0000029  17183656  PLoS ONE         plos
# 17     17  10.1371/journal.pone.0000082  17183714  PLoS ONE         plos
# 18     18  10.1371/journal.pone.0000118  17205122  PLoS ONE         plos
# 19     19  10.1371/journal.pone.0000032  17183660  PLoS ONE         plos
# 20     20  10.1371/journal.pone.0000065  17183696  PLoS ONE         plos
# 21     21  10.1371/journal.pone.0000098  17183730  PLoS ONE         plos
# 22     22  10.1371/journal.pone.0000015  17183641  PLoS ONE         plos
# 23     23  10.1371/journal.pone.0000048  17183677  PLoS ONE         plos
# 24     24  10.1371/journal.pone.0000051  17183681  PLoS ONE         plos
# 25     25  10.1371/journal.pone.0000001  17183631  PLoS ONE         plos
# 26     26  10.1371/journal.pone.0000034  17183662  PLoS ONE         plos
# 27     27  10.1371/journal.pone.0000067  17183698  PLoS ONE         plos
# 28     28  10.1371/journal.pone.0000017  17183643  PLoS ONE         plos
# 29     29  10.1371/journal.pone.0000070  17183702  PLoS ONE         plos
# 30     30  10.1371/journal.pone.0000020  17183647  PLoS ONE         plos
# 31     31  10.1371/journal.pone.0000053  17183683  PLoS ONE         plos
# 32     32  10.1371/journal.pone.0000086  17183717  PLoS ONE         plos
# 33     33  10.1371/journal.pone.0000003  17183657  PLoS ONE         plos
# 34     34  10.1371/journal.pone.0000036  17183664  PLoS ONE         plos
# 35     35  10.1371/journal.pone.0000069  17183700  PLoS ONE         plos
# 36     36  10.1371/journal.pone.0000121  17205125  PLoS ONE         plos
# 37     37  10.1371/journal.pone.0000072  17183704  PLoS ONE         plos
# 38     38  10.1371/journal.pone.0000022  17183649  PLoS ONE         plos
# 39     39  10.1371/journal.pone.0000055  17183685  PLoS ONE         plos
# 40     40  10.1371/journal.pone.0000088  17183719  PLoS ONE         plos
# 41     41  10.1371/journal.pone.0000005  17183679  PLoS ONE         plos
# 42     42  10.1371/journal.pone.0000038  17183666  PLoS ONE         plos
# 43     43  10.1371/journal.pone.0000091  17183723  PLoS ONE         plos
# 44     44  10.1371/journal.pone.0000041  17183670  PLoS ONE         plos
# 45     45  10.1371/journal.pone.0000074  17183706  PLoS ONE         plos
# 46     46  10.1371/journal.pone.0000024  17183651  PLoS ONE         plos
# 47     47  10.1371/journal.pone.0000057  17183687  PLoS ONE         plos
# 48     48  10.1371/journal.pone.0000007  17183701  PLoS ONE         plos
# 49     49  10.1371/journal.pone.0000060  17183691  PLoS ONE         plos
#
#                publisher_name  \
# 0   Public Library of Science
# 1   Public Library of Science
# 2   Public Library of Science
# 3   Public Library of Science
# 4   Public Library of Science
# 5   Public Library of Science
# 6   Public Library of Science
# 7   Public Library of Science
# 8   Public Library of Science
# 9   Public Library of Science
# 10  Public Library of Science
# 11  Public Library of Science
# 12  Public Library of Science
# 13  Public Library of Science
# 14  Public Library of Science
# 15  Public Library of Science
# 16  Public Library of Science
# 17  Public Library of Science
# 18  Public Library of Science
# 19  Public Library of Science
# 20  Public Library of Science
# 21  Public Library of Science
# 22  Public Library of Science
# 23  Public Library of Science
# 24  Public Library of Science
# 25  Public Library of Science
# 26  Public Library of Science
# 27  Public Library of Science
# 28  Public Library of Science
# 29  Public Library of Science
# 30  Public Library of Science
# 31  Public Library of Science
# 32  Public Library of Science
# 33  Public Library of Science
# 34  Public Library of Science
# 35  Public Library of Science
# 36  Public Library of Science
# 37  Public Library of Science
# 38  Public Library of Science
# 39  Public Library of Science
# 40  Public Library of Science
# 41  Public Library of Science
# 42  Public Library of Science
# 43  Public Library of Science
# 44  Public Library of Science
# 45  Public Library of Science
# 46  Public Library of Science
# 47  Public Library of Science
# 48  Public Library of Science
# 49  Public Library of Science
#
#                                               authors  \
# 0   ['Justin A. Harris', 'Ehsan Arabzadeh', 'Adrie...
# 1          ['Maxim V. Kapralov', 'Dmitry A. Filatov']
# 2   ['Andrey Rzhetsky', 'Tian Zheng', 'Chani Weinr...
# 3   ['Jingchun Zhu', 'Ashwini Jambhekar', 'Aaron S...
# 4   ['Matthew E. Falagas', 'Konstantinos N. Fragou...
# 5                ['Sara O. Dean', 'James A. Spudich']
# 6   ['Samantha Kerry', 'Michael TeKippe', 'Nathan ...
# 7   ['Colin A. Russell', 'Leslie A. Real', 'David ...
# 8   ['Zhihua Jiang', 'Jennifer J. Michal', 'Galen ...
# 9   ['Fatema A. Legrand', 'Douglas F. Nixon', 'Chr...
# 10  ['Markus Ralser', 'Gino Heeren', 'Michael Brei...
# 11  ['David G. Haskell', 'Jonathan P. Evans', 'Nei...
# 12  ['Yuuki Hayashi', 'Takuyo Aita', 'Hitoshi Toyo...
# 13  ['Pia Leppänen', 'Ivana Kholová', 'Anssi J. Mä...
# 14  ['Alon Goren', 'Giora Simchen', 'Eitan Fibach'...
# 15  ['Wataru Sonoyama', 'Yi Liu', 'Dianji Fang', '...
# 16  ['Helmy Rachman', 'Nayoung Kim', 'Timo Ulrichs...
# 17  ['B. Nelson Chau', 'Chris W. Pan', 'Jean Y.J. ...
# 18            ['Seth W. Coleman', 'Gil G. Rosenthal']
# 19  ['Marina Bacac', 'Paolo Provero', 'Nathalie Ma...
# 20  ['Thomas Ruf', 'Teresa Valencak', 'Frieda Tata...
# 21  ['Claudia Arce', 'Carlos Pérez-Plasencia', 'Au...
# 22  ['Masato Nagaoka', 'Uichi Koshimizu', 'Shinsuk...
# 23  ['Matthias Nahrendorf', 'Ralph Weissleder', 'G...
# 24  ['Yoshitake Sano', 'Tadashi Nakaya', 'Steve Pe...
# 25  ['Maria C Almeida', 'Alexandre A Steiner', 'Lu...
# 26  ['Karl Maurer', 'John Cooper', 'Marcelo Caraba...
# 27     ['Rajesh Khanna', 'Qi Li', 'Elise F. Stanley']
# 28  ['Eshwar Mahenthiralingam', 'Adam Baldwin', 'P...
# 29  ['Iván L. Calderón', 'Felipe A. Arenas', 'José...
# 30    ['John M. Drake', 'Suok Kai Chew', 'Stefan Ma']
# 31  ['Laura A. Díaz-Martínez', 'Juan F. Giménez-Ab...
# 32  ['Christian Beste', 'Carsten Saft', 'Jürgen An...
# 33  ['Matthew R. Goddard', 'Jessica Leigh', 'Andre...
# 34  ['Roberto C. Cañamero', 'Hernán Boccalandro', ...
# 35  ['Lester M. Shulman', 'Yossi Manor', 'Danit So...
# 36  ['Rony Zachariah', 'Anthony David Harries', 'M...
# 37  ['Staffan Bensch', 'Henrik Andrén', 'Bengt Han...
# 38  ['Janine H. Stubbe', 'Dorret I. Boomsma', 'Jac...
# 39  ['Hendrik P.J. Bonarius', 'Frank Baas', 'Ester...
# 40       ['Yi Xing', 'Karen Kapur', 'Wing Hung Wong']
# 41                           ['John P. A. Ioannidis']
# 42  ['Rafal Farjo', 'Jeff Skaggs', 'Alexander B. Q...
# 43               ['Paul de Groot', 'R.W. Veldhuizen']
# 44  ['José M. Malpica', 'Soledad Sacristán', 'Auro...
# 45  ['Ines Van Bocxlaer', 'Kim Roelants', 'S.D. Bi...
# 46  ['Taisheng Li', 'Jing Xie', 'Yuxian He', 'Hong...
# 47  ['Sebastian E. B. Graefe', 'Thomas Streichert'...
# 48  ['Casper J Breuker', 'James S Patterson', 'Chr...
# 49  ['Devon D. Brewer', 'John J. Potterat', 'Steph...
#
#                       editors  \
# 0     ['Hernan Lopez-Schier']
# 1        ['Konrad Scheffler']
# 2               ['Nick Monk']
# 3     ['Gustavo Stolovitzky']
# 4          ['Bernhard Baune']
# 5           ['Robert Insall']
# 6   ['Eleftherios Mylonakis']
# 7          ['Matthew Baylis']
# 8               ['Neil Hall']
# 9           ['Derya Unutmaz']
# 10         ['Guilhem Janbon']
# 11         ['Will Cresswell']
# 12    ['Suzannah Rutherford']
# 13    ['Mihail Blagosklonny']
# 14             ['Axel Imhof']
# 15            ['Marie Csete']
# 16          ['Derya Unutmaz']
# 17     ['Christopher Arendt']
# 18           ['Tom Tregenza']
# 19   ['Mikhail Blagosklonny']
# 20           ['Steven Chown']
# 21   ['Mikhail Blagosklonny']
# 22           ['Thomas Zwaka']
# 23           ['Thomas Zwaka']
# 24         ['Ulrich Mueller']
# 25      ['Alejandro Aballay']
# 26          ['Jörg Hoheisel']
# 27         ['Richard Banati']
# 28        ['Steven Salzberg']
# 29      ['Christophe Herman']
# 30         ['Bernhard Baune']
# 31          ['Beth Sullivan']
# 32         ['Bernhard Baune']
# 33           ['James Fraser']
# 34            ['Ivan Baxter']
# 35           ['Barry Schoub']
# 36             ['Dee Carter']
# 37           ['Neil Gemmell']
# 38       ['Mitchell Feldman']
# 39           ['Etienne Joly']
# 40            ['Janet Kelso']
# 41         ['Oliver Hofmann']
# 42           ['Thomas Zwaka']
# 43           ['Thomas Zwaka']
# 44         ['Angus Buckling']
# 45      ['Michael Hofreiter']
# 46          ['Derya Unutmaz']
# 47          ['Derya Unutmaz']
# 48    ['Suzannah Rutherford']
# 49           ['Etienne Joly']
#
#                                              subjects  \
# 0   ['Research Article', 'Neuroscience/Sensory Sys...
# 1        ['Research Article', 'Evolutionary Biology']
# 2   ['Research Article', 'Cell Biology', 'Computat...
# 3   ['Research Article', 'Genetics and Genomics/Fu...
# 4   ['Research Article', 'Public Health and Epidem...
# 5                ['Research Article', 'Cell Biology']
# 6   ['Research Article', 'Immunology/Innate Immuni...
# 7   ['Research Article', 'Ecology', 'Infectious Di...
# 8   ['Research Article', 'Genetics and Genomics/An...
# 9   ['Research Article', 'Pediatrics and Child Hea...
# 10  ['Research Article', 'Biochemistry', 'Cell Bio...
# 11  ['Research Article', 'Ecology', 'Science Policy']
# 12  ['Research Article', 'Biophysics', 'Evolutiona...
# 13          ['Research Article', 'Molecular Biology']
# 14  ['Research Article', 'Molecular Biology/Chroma...
# 15  ['Research Article', 'Biotechnology/Bioenginee...
# 16  ['Research Article', 'Cell Biology', 'Diabetes...
# 17  ['Research Article', 'Cell Biology/Cell Growth...
# 18  ['Research Article', 'Ecology/Behavioral Ecolo...
# 19      ['Research Article', 'Oncology', 'Pathology']
# 20  ['Research Article', 'Cell Biology', 'Ecology'...
# 21  ['Research Article', 'Genetics and Genomics/Ep...
# 22  ['Research Article', 'Developmental Biology', ...
# 23  ['Research Article', 'Radiology and Medical Im...
# 24  ['Research Article', 'Biochemistry/Cell Signal...
# 25  ['Research Article', 'Immunology/Immunomodulat...
# 26  ['Research Article', 'Biochemistry', 'Biotechn...
# 27  ['Research Article', 'Biochemistry', 'Neurosci...
# 28  ['Research Article', 'Computational Biology', ...
# 29  ['Research Article', 'Biochemistry', 'Microbio...
# 30  ['Research Article', 'Infectious Diseases', 'P...
# 31               ['Research Article', 'Cell Biology']
# 32  ['Research Article', 'Neuroscience/Behavioral ...
# 33  ['Research Article', 'Evolutionary Biology', '...
# 34              ['Research Article', 'Plant Biology']
# 35  ['Research Article', 'Evolutionary Biology', '...
# 36  ['Research Article', 'Infectious Diseases/HIV ...
# 37  ['Research Article', 'Ecology', 'Evolutionary ...
# 38  ['Research Article', 'Genetics and Genomics/Po...
# 39  ['Research Article', 'Biotechnology', 'Immunol...
# 40  ['Research Article', 'Genetics and Genomics/Bi...
# 41  ['Research Article', 'Science Policy', 'Ecolog...
# 42  ['Research Article', 'Ophthalmology', 'Genetic...
# 43  ['Research Article', 'Cardiovascular Disorders...
# 44  ['Research Article', 'Ecology', 'Evolutionary ...
# 45       ['Research Article', 'Evolutionary Biology']
# 46  ['Research Article', 'Infectious Diseases', 'R...
# 47  ['Research Article', 'Infectious Diseases', 'G...
# 48  ['Research Article', 'Evolutionary Biology', '...
# 49  ['Research Article', 'Public Health and Epidem...
#
#                                                 title  \
# 0   ['Factors Affecting Frequency Discrimination o...
# 1   ['Molecular Adaptation during Adaptive Radiati...
# 2      ['Self-Correcting Maps of Molecular Pathways']
# 3   ['A Bayesian Network Driven Approach to Model ...
# 4   ['A Comparative Study on the Cost of New Antib...
# 5   ["Rho Kinase's Role in Myosin Recruitment to t...
# 6   ['GATA Transcription Factor Required for Immun...
# 7   ['Spatial Control of Rabies on Heterogeneous L...
# 8   ['Cross Species Association Examination of UCN...
# 9   ['Strong HIV-1-Specific T Cell Responses in HI...
# 10  ['Triose Phosphate Isomerase Deficiency Is Cau...
# 11  ['Depauperate Avifauna in Plantations Compared...
# 12  ['Experimental Rugged Fitness Landscape in Pro...
# 13         ['Short and Long-Term Effects of hVEGF-A']
# 14  ['Fine Tuning of Globin Gene Expression by DNA...
# 15  ['Mesenchymal Stem Cell-Mediated Functional To...
# 16  ['Critical Role of Methylglyoxal and AGE in My...
# 17  ['Separation of Anti-Proliferation and Anti-Ap...
# 18  ['Swordtail Fry Attend to Chemical and Visual ...
# 19  ['A Mouse Stromal Response to Tumor Invasion P...
# 20  ['Running Speed in Mammals Increases with Musc...
# 21  ['A Proof-Of-Principle Study of Epigenetic The...
# 22  ['E-Cadherin-Coated Plates Maintain Pluripoten...
# 23  ['Does FXIII Deficiency Impair Wound Healing a...
# 24  ["Physiological Mouse Brain Aβ Levels Are Not ...
# 25  ['Neural Substrate of Cold-Seeking Behavior in...
# 26  ['Electrochemically Generated Acid and Its Con...
# 27  ['‘Fractional Recovery’ Analysis of a Presynap...
# 28  ['Multilocus Sequence Typing Breathes Life int...
# 29  ['Catalases Are NAD(P)H-Dependent Tellurite Re...
# 30  ['Societal Learning in Epidemics: Intervention...
# 31  ['PIASγ Is Required for Faithful Chromosome Se...
# 32       ["Error Processing in Huntington's Disease"]
# 33  ['Invasion and Persistence of a Selfish Gene i...
# 34  ['Use of Confocal Laser as Light Source Reveal...
# 35  ['Neurovirulent Vaccine-Derived Polioviruses i...
# 36  ['Acceptance of Anti-Retroviral Therapy among ...
# 37  ['Selection for Heterozygosity Gives Hope to a...
# 38  ['Genetic Influences on Exercise Participation...
# 39  ['Monitoring the T-Cell Receptor Repertoire at...
# 40  ['Probe Selection and Expression Index Computa...
# 41  ['Concentration of the Most-Cited Papers in th...
# 42  ['Efficient Non-Viral Ocular Gene Transfer wit...
# 43  ['Human Coronary Artery Remodeling, Beginning ...
# 44  ['Association and Host Selectivity in Multi-Ho...
# 45  ['Late Cretaceous Vicariance in Gondwanan Amph...
# 46  ['Long-Term Persistence of Robust Antibody and...
# 47  ['Genes from Chagas Susceptibility Loci That A...
# 48  ['A Single Basis for Developmental Buffering o...
# 49  ['A Large Specific Deterrent Effect of Arrest ...
#
#                              alt_title             date_pub  \
# 0      ['Vibrotactile Discrimination']  2006-12-20 00:00:00
# 1                               [None]  2006-12-20 00:00:00
# 2         ['Self-Correcting Pathways']  2006-12-20 00:00:00
# 3    ['Nitric Oxide Response Network']  2006-12-20 00:00:00
# 4                ['Cost of New Drugs']  2006-12-20 00:00:00
# 5        ['Rho Kinase in Cytokinesis']  2006-12-27 00:00:00
# 6         ['ELT-2 in Innate Immunity']  2006-12-20 00:00:00
# 7        ['Spatial Control of Rabies']  2006-12-20 00:00:00
# 8   ['UCN3 and CRHR2 for Antiobesity']  2006-12-20 00:00:00
# 9     ['Tregs in HIV-Exposed Infants']  2006-12-20 00:00:00
# 10        ['Analysis of TPI Variants']  2006-12-20 00:00:00
# 11        ['Avifauna and Forest Loss']  2006-12-20 00:00:00
# 12    ['In Vitro Molecular Evolution']  2006-12-20 00:00:00
# 13                         ['hVEGF-A']  2006-12-20 00:00:00
# 14  ['Fine Tuning by DNA Methylation']  2006-12-20 00:00:00
# 15              ['Tooth Regeneration']  2006-12-20 00:00:00
# 16  ['Methylglyoxal in MTB Infection']  2006-12-20 00:00:00
# 17           ['RB Inhibits Apoptosis']  2006-12-20 00:00:00
# 18  ['Fry Use Chemical & Visual Cues']  2006-12-27 00:00:00
# 19      ['Stromal Response to Tumors']  2006-12-20 00:00:00
# 20   ['Running Speed and Fatty Acids']  2006-12-20 00:00:00
# 21    ['Epigenetic Therapy of Cancer']  2006-12-20 00:00:00
# 22         ['ES Cells as Single Cell']  2006-12-20 00:00:00
# 23                ['FXIII Deficiency']  2006-12-20 00:00:00
# 24      ['APP Phosphorylation and Aβ']  2006-12-20 00:00:00
# 25    ['Neural Basis of Cold Seeking']  2006-12-20 00:00:00
# 26             ['DNA Array Synthesis']  2006-12-20 00:00:00
# 27       ['A Synaptotagmin-1 Complex']  2006-12-20 00:00:00
# 28   ['Bringing Life to a Metagenome']  2006-12-20 00:00:00
# 29      ['Catalases Reduce Tellurite']  2006-12-20 00:00:00
# 30  ['Societal Learning in Epidemics']  2006-12-20 00:00:00
# 31           ['Centromere Separation']  2006-12-20 00:00:00
# 32          ['Error Processing in HD']  2006-12-20 00:00:00
# 33  ['Metazoan Selfish Gene Dynamics']  2006-12-20 00:00:00
# 34    ['Autonomy of Stomata Function']  2006-12-20 00:00:00
# 35    ['Neurovirulent VDPV in Sewage']  2006-12-20 00:00:00
# 36         ['Transport Costs and ART']  2006-12-27 00:00:00
# 37    ['Inbred Wolves Heterozygosity']  2006-12-20 00:00:00
# 38  ['Genetic Influences on Exercise']  2006-12-20 00:00:00
# 39                        ['T-Arrays']  2006-12-20 00:00:00
# 40  ['Probe Selection of Exon Arrays']  2006-12-20 00:00:00
# 41               ['Most-Cited Papers']  2006-12-20 00:00:00
# 42  ['Non-Viral Ocular Gene Transfer']  2006-12-20 00:00:00
# 43     ['Atherosclerosis, Remodeling']  2006-12-20 00:00:00
# 44       ['Associations in Pathogens']  2006-12-20 00:00:00
# 45  ['Gondwanan Amphibian Vicariance']  2006-12-20 00:00:00
# 46      ['Follow-Up of SARS Patients']  2006-12-20 00:00:00
# 47     ['Chagas Susceptibility Genes']  2006-12-20 00:00:00
# 48         ['Developmental Buffering']  2006-12-20 00:00:00
# 49      ['Deterrent Effect of Arrest']  2006-12-20 00:00:00
#
#                date_rec                                           abstract  \
# 0   2006-10-19 00:00:00  BackgroundMeasuring perceptual judgments about...
# 1   2006-08-07 00:00:00  Background“Explosive” adaptive radiations on i...
# 2   2006-09-15 00:00:00  Reliable and comprehensive maps of molecular p...
# 3   2006-09-16 00:00:00  The transcriptional response to exogenously su...
# 4   2006-08-28 00:00:00  BackgroundDrug treatment is becoming more expe...
# 5   2006-10-16 00:00:00  BackgroundMyosin II recruitment to the equator...
# 6   2006-11-09 00:00:00  In the past decade, Caenorhabditis elegans has...
# 7   2006-09-21 00:00:00  Rabies control in terrestrial wildlife reservo...
# 8   2006-10-07 00:00:00  BackgroundObesity now constitutes a leading gl...
# 9   2006-11-05 00:00:00  BackgroundIn utero transmission of HIV-1 occur...
# 10  2006-09-20 00:00:00  Triosephosphate isomerase (TPI) deficiency is ...
# 11  2006-08-25 00:00:00  Native forests are shrinking worldwide, causin...
# 12  2006-08-07 00:00:00  The fitness landscape in sequence space determ...
# 13  2006-08-21 00:00:00  We have generated a transgenic mouse where hVE...
# 14  2006-09-11 00:00:00  Expression patterns in the globin gene cluster...
# 15  2006-09-12 00:00:00  Mesenchymal stem cell-mediated tissue regenera...
# 16  2006-08-11 00:00:00  Apoptosis and activation of macrophages play a...
# 17  2006-10-09 00:00:00  BackgroundThe human retinoblastoma susceptibil...
# 18  2006-10-09 00:00:00  Predation pressure and energy requirements pre...
# 19  2006-08-18 00:00:00  Primary and metastatic tumor growth induces ho...
# 20  2006-09-21 00:00:00  Polyunsaturated fatty acids (PUFAs) are import...
# 21  2006-09-13 00:00:00  BackgroundAberrant DNA methylation and histone...
# 22  2006-09-07 00:00:00  Embryonic stem (ES) cells cultured on gelatin-...
# 23  2006-09-20 00:00:00  Inadequate healing of myocardial infarction ma...
# 24  2006-08-16 00:00:00  BackgroundAmyloid-β peptide species ending at ...
# 25  2006-08-08 00:00:00  Systemic inflammation is a leading cause of ho...
# 26  2006-08-18 00:00:00  An addressable electrode array was used for th...
# 27  2006-10-12 00:00:00  BackgroundThe integral synaptic vesicle protei...
# 28  2006-08-22 00:00:00  Shot-gun sequencing of DNA isolated from the e...
# 29  2006-10-13 00:00:00  Reactive oxygen species damage intracellular t...
# 30  2006-08-09 00:00:00  BackgroundRapid response to outbreaks of emerg...
# 31  2006-10-11 00:00:00  BackgroundThe precision of the metaphase-anaph...
# 32  2006-11-06 00:00:00  BackgroundHuntington's disease (HD) is a genet...
# 33  2006-08-01 00:00:00  BackgroundHoming endonuclease genes (HEGs) are...
# 34  2006-08-07 00:00:00  In most terrestrial plants, stomata open durin...
# 35  2006-08-07 00:00:00  BackgroundVaccine-derived polioviruses (VDPVs)...
# 36  2006-08-25 00:00:00  BackgroundA study was conducted among newly re...
# 37  2006-09-08 00:00:00  Recent analyses have questioned the usefulness...
# 38  2006-09-13 00:00:00  BackgroundA sedentary lifestyle remains a majo...
# 39  2006-09-12 00:00:00  The adaptive immune system recognizes billions...
# 40  2006-09-11 00:00:00  BackgroundThere is great current interest in d...
# 41  2006-08-14 00:00:00  BackgroundA minority of scientific journals pu...
# 42  2006-09-19 00:00:00  BackgroundThe eye is an excellent candidate fo...
# 43  2006-10-04 00:00:00  Background, Aims of the StudyThe objective of ...
# 44  2006-08-31 00:00:00  The distribution of multi-host pathogens over ...
# 45  2006-09-07 00:00:00  Overseas dispersals are often invoked when Sou...
# 46  2006-08-21 00:00:00  Most of the individuals infected with SARS cor...
# 47  2006-10-01 00:00:00  Variation between inbred mice of susceptibilit...
# 48  2006-08-09 00:00:00  The nature of developmental buffering processe...
# 49  2006-10-20 00:00:00  BackgroundPrior research suggests that arrest,...
#
#                                                  body
# 0   IntroductionMany investigations of sensory pro...
# 1   IntroductionThe most dramatic “bursts” of adap...
# 2   IntroductionScientific innovation often procee...
# 3   IntroductionNitric oxide (NO·) is a critical m...
# 4   IntroductionThe investment of societies around...
# 5   IntroductionCytokinesis involves the formation...
# 6   IntroductionThe study of innate immunity recei...
# 7   IntroductionAn emerging paradigm for the sprea...
# 8   IntroductionObesity has increased at a fast ra...
# 9   IntroductionVertical transmission of HIV-1 can...
# 10  IntroductionTriosephosphate isomerase deficien...
# 11  IntroductionNative forests are shrinking world...
# 12  IntroductionIn vitro molecular evolution can b...
# 13  IntroductionVascular endothelial growth factor...
# 14  IntroductionGenome wide DNA methylation is set...
# 15  IntroductionRegeneration of a functional and l...
# 16  IntroductionTuberculosis (TB) represents a maj...
# 17  IntroductionThe retinoblastoma susceptibility ...
# 18  IntroductionPredation pressure is a primary fo...
# 19  IntroductionMalignant tumors are complex cellu...
# 20  IntroductionComparative studies on locomotor p...
# 21  IntroductionAberrant gene transcriptions resul...
# 22  IntroductionCell-cell and cell-matrix interact...
# 23  IntroductionInadequate healing of myocardial i...
# 24  IntroductionAlzheimer's disease (AD) is charac...
# 25  IntroductionDeep body temperature (Tb) is regu...
# 26  IntroductionRapid developments in the field of...
# 27  IntroductionTransmitter release is triggered b...
# 28  INTRODUCTIONThe ability to assemble complete g...
# 29  IntroductionMolecular oxygen accepts electrons...
# 30  IntroductionRapidly spreading outbreaks of inf...
# 31  IntroductionCohesion between sister chromatids...
# 32  IntroductionHuntington's disease (HD) is an au...
# 33  IntroductionHoming endonuclease genes (HEGs) a...
# 34  IntroductionStomatal pores are located on the ...
# 35  IntroductionEnhanced inactivated polio vaccine...
# 36  IntroductionTuberculosis (TB) is one of the mo...
# 37  IntroductionInbreeding is more likely to take ...
# 38  IntroductionRegular exercisers have reduced ca...
# 39  IntroductionT cells are key players in the ant...
# 40  IntroductionMicroarrays have become one of the...
# 41  IntroductionDespite a very large number of sci...
# 42  IntroductionThe eye is comprised of several sp...
# 43  IntroductionCoronary artery morphology and dia...
# 44  IntroductionPathogens have highly variable hos...
# 45  IntroductionEver since Alfred Wegener's theory...
# 46  IntroductionSARS, or severe acute respiratory ...
# 47  IntroductionChagas' disease severely affects a...
# 48  IntroductionDevelopmental buffering is an impo...
# 49  IntroductionCriminologists have long studied t...
