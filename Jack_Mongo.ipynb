# %%
## CONNECTING TO MONGO

from pymongo import MongoClient
# pprint library is used to make the output look more pretty
from pprint import pprint
# connect to MongoDB, change the << MONGODB URL >> to reflect your own connection string
client = MongoClient('mongodb://jmp3mk:Zlo2bLgAgoR3V6Pq@cluster0-shard-00-00-dsbst.mongodb.net:27017,cluster0-shard-00-01-dsbst.mongodb.net:27017,cluster0-shard-00-02-dsbst.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')
db=client.admin
# Issue the serverStatus command and print the results
serverStatusResult=db.command("serverStatus")
#pprint(serverStatusResult)

# %%
## PUTTING SAMPLE DATA INTO MONGO

from pymongo import MongoClient
from random import randint
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient('mongodb://jmp3mk:Zlo2bLgAgoR3V6Pq@cluster0-shard-00-00-dsbst.mongodb.net:27017,cluster0-shard-00-01-dsbst.mongodb.net:27017,cluster0-shard-00-02-dsbst.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')
db=client.business
#Step 2: Create sample data
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']
for x in range(1, 501):
    business = {
        'name' : names[randint(0, (len(names)-1))] + ' ' + names[randint(0, (len(names)-1))]  + ' ' + company_type[randint(0, (len(company_type)-1))],
        'rating' : randint(1, 5),
        'cuisine' : company_cuisine[randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via isnert_one
    result=db.reviews.insert_one(business)
    #Step 4: Print to the console the ObjectID of the new document
    #print('Created {0} of 500 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
# Out:
# finished creating 500 business reviews

# %%
from pymongo import MongoClient
import json
import xmltodict

f=open('/Users/jackprominski/Desktop/PLOS_PMC_comm/PLoS_One/PMC5617228.nxml')
data = xmltodict.parse(f.read())
data_json=json.dumps(data)
#data_json

#with open('data.json', 'w') as outfile:
#    json.dump(data, outfile)

client = MongoClient('mongodb://jmp3mk:Zlo2bLgAgoR3V6Pq@cluster0-shard-00-00-dsbst.mongodb.net:27017,cluster0-shard-00-01-dsbst.mongodb.net:27017,cluster0-shard-00-02-dsbst.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')
db=client.Corpus
#result=db.Corpus.insert_one(data_json)

from bson import json_util
data_bson = json_util.loads(data_json)
data_bson


#result=db.Corpus.insert_one(data_bson)
# Out:
# {'article': {'@article-type': 'research-article',
#   '@xmlns:mml': 'http://www.w3.org/1998/Math/MathML',
#   '@xmlns:xlink': 'http://www.w3.org/1999/xlink',
#   'back': {'ack': {'p': [{'#text': 'This work was supported by National Key Research and Development Program of China (Grant No. 2016YFA0200903) () and the National Science Foundation (Grant No. 81401517) ().',
#       'ext-link': [{'#text': 'http://www.most.gov.cn/',
#         '@ext-link-type': 'uri',
#         '@xlink:href': 'http://www.most.gov.cn/'},
#        {'#text': 'http://www.nsfc.gov.cn/',
#         '@ext-link-type': 'uri',
#         '@xlink:href': 'http://www.nsfc.gov.cn/'}]},
#      'The authors gratefully acknowledge Chao Wang, Yanwei Yang and Xin Wang for their excellent technical assistance on the animal management, pathological studies and chromosome aberration test.']},
#    'glossary': {'def-list': {'def-item': [{'def': {'p': 'silver nanoparticle'},
#        'term': 'AgNP'},
#       {'def': {'p': 'cyclophophamide'}, 'term': 'CPA'},
#       {'def': {'p': 'colchicine'}, 'term': 'COL'},
#       {'def': {'p': 'intravenous injection'}, 'term': 'i.v.'}]},
#     'title': 'Abbreviations'},
#    'ref-list': {'ref': [{'@id': 'pone.0185554.ref001',
#       'label': '1',
#       'mixed-citation': {'#text': ', , , , , . . . ;:\n ; PubMed Central PMCID: PMC3430588.',
#        '@publication-type': 'journal',
#        'article-title': 'Genotoxicity and molecular response of silver nanoparticle (NP)-based hydrogel',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1186/1477-3155-10-16',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1186/1477-3155-10-16'}},
#        'fpage': '16',
#        'name': [{'given-names': 'L', 'surname': 'Xu'},
#         {'given-names': 'X', 'surname': 'Li'},
#         {'given-names': 'T', 'surname': 'Takemura'},
#         {'given-names': 'N', 'surname': 'Hanagata'},
#         {'given-names': 'G', 'surname': 'Wu'},
#         {'given-names': 'LL', 'surname': 'Chou'}],
#        'pub-id': {'#text': '22548743', '@pub-id-type': 'pmid'},
#        'source': 'Journal of nanobiotechnology',
#        'volume': '10',
#        'year': '2012'}},
#      {'@id': 'pone.0185554.ref002',
#       'label': '2',
#       'mixed-citation': {'#text': ', , . . . ;:\n ; PubMed Central PMCID: PMC3762079.',
#        '@publication-type': 'journal',
#        'article-title': 'Mechanisms of nanoparticle-induced oxidative stress and toxicity',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1155/2013/942916',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1155/2013/942916'}},
#        'fpage': '942916',
#        'name': [{'given-names': 'A', 'surname': 'Manke'},
#         {'given-names': 'L', 'surname': 'Wang'},
#         {'given-names': 'Y', 'surname': 'Rojanasakul'}],
#        'pub-id': {'#text': '24027766', '@pub-id-type': 'pmid'},
#        'source': 'BioMed research international',
#        'volume': '2013',
#        'year': '2013'}},
#      {'@id': 'pone.0185554.ref003',
#       'label': '3',
#       'mixed-citation': {'#text': ', , , , , . . . ;:–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Genotoxicity of silver and titanium dioxide nanoparticles in bone marrow cells of rats in vivo',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.tox.2013.11.012',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.tox.2013.11.012'}},
#        'fpage': '86',
#        'lpage': '91',
#        'name': [{'given-names': 'MM', 'surname': 'Dobrzynska'},
#         {'given-names': 'A', 'surname': 'Gajowik'},
#         {'given-names': 'J', 'surname': 'Radzikowska'},
#         {'given-names': 'A', 'surname': 'Lankoff'},
#         {'given-names': 'M', 'surname': 'Dusinska'},
#         {'given-names': 'M', 'surname': 'Kruszewski'}],
#        'pub-id': {'#text': '24321264', '@pub-id-type': 'pmid'},
#        'source': 'Toxicology',
#        'volume': '315',
#        'year': '2014'}},
#      {'@id': 'pone.0185554.ref004',
#       'label': '4',
#       'mixed-citation': {'#text': '. . . ;:–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Estimation of TiO(2) nanoparticle-induced genotoxicity persistence and possible chronic gastritis-induction in mice',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.fct.2015.05.018',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.fct.2015.05.018'}},
#        'fpage': '76',
#        'lpage': '83',
#        'name': {'given-names': 'HR', 'surname': 'Mohamed'},
#        'pub-id': {'#text': '26072100', '@pub-id-type': 'pmid'},
#        'source': 'Food and chemical toxicology: an international journal published for the British Industrial Biological Research Association',
#        'volume': '83',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref005',
#       'label': '5',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Single-Cell Mechanics Provides an Effective Means To Probe in Vivo Interactions between Alveolar Macrophages and Silver Nanoparticles',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1021/acs.jpcb.5b07656',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1021/acs.jpcb.5b07656'}},
#        'etal': 'et al',
#        'fpage': '15118',
#        'issue': '49',
#        'lpage': '29',
#        'name': [{'given-names': 'YX', 'surname': 'Liu'},
#         {'given-names': 'A', 'surname': 'Karsai'},
#         {'given-names': 'DS', 'surname': 'Anderson'},
#         {'given-names': 'RM', 'surname': 'Silva'},
#         {'given-names': 'DL', 'surname': 'Uyeminami'},
#         {'given-names': 'LS', 'surname': 'Van Winkle'}],
#        'pub-id': {'#text': '26562364', '@pub-id-type': 'pmid'},
#        'source': 'The journal of physical chemistry B',
#        'volume': '119',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref006',
#       'label': '6',
#       'mixed-citation': {'#text': ', , . . . :–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Silver nanoparticles of 70 nm and 20 nm affect differently the biology of human neutrophils',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/1547691X.2015.1106622',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/1547691X.2015.1106622'}},
#        'fpage': '1',
#        'lpage': '11',
#        'name': [{'given-names': 'M', 'surname': 'Poirier'},
#         {'given-names': 'JC', 'surname': 'Simard'},
#         {'given-names': 'D', 'surname': 'Girard'}],
#        'pub-id': {'#text': '26619040', '@pub-id-type': 'pmid'},
#        'source': 'Journal of immunotoxicology',
#        'volume': '2015'}},
#      {'@id': 'pone.0185554.ref007',
#       'label': '7',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Male- and female-derived somatic and germ cell-specific toxicity of silver nanoparticles in mouse',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/17435390.2015.1073396',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/17435390.2015.1073396'}},
#        'etal': 'et al',
#        'fpage': '361',
#        'issue': '3',
#        'lpage': '73',
#        'name': [{'given-names': 'JW', 'surname': 'Han'},
#         {'given-names': 'JK', 'surname': 'Jeong'},
#         {'given-names': 'S', 'surname': 'Gurunathan'},
#         {'given-names': 'YJ', 'surname': 'Choi'},
#         {'given-names': 'J', 'surname': 'Das'},
#         {'given-names': 'DN', 'surname': 'Kwon'}],
#        'pub-id': {'#text': '26470004', '@pub-id-type': 'pmid'},
#        'source': 'Nanotoxicology',
#        'volume': '10',
#        'year': '2016'}},
#      {'@id': 'pone.0185554.ref008',
#       'label': '8',
#       'mixed-citation': {'#text': ', , . . . ;():–.  ; PubMed Central PMCID: PMC4268425.',
#        '@publication-type': 'journal',
#        'article-title': 'Silver nanoparticle-induced oxidative stress-dependent toxicity in Sprague-Dawley rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1007/s11010-014-2252-7',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1007/s11010-014-2252-7'}},
#        'fpage': '257',
#        'issue': '1–2',
#        'lpage': '68',
#        'name': [{'given-names': 'AK', 'surname': 'Patlolla'},
#         {'given-names': 'D', 'surname': 'Hackett'},
#         {'given-names': 'PB', 'surname': 'Tchounwou'}],
#        'pub-id': {'#text': '25355157', '@pub-id-type': 'pmid'},
#        'source': 'Molecular and cellular biochemistry',
#        'volume': '399',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref009',
#       'label': '9',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Twenty-eight-day inhalation toxicity study of silver nanoparticles in Sprague-Dawley rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1080/08958370701432108',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1080/08958370701432108'}},
#        'etal': 'et al',
#        'fpage': '857',
#        'issue': '10',
#        'lpage': '71',
#        'name': [{'given-names': 'JH', 'surname': 'Ji'},
#         {'given-names': 'JH', 'surname': 'Jung'},
#         {'given-names': 'SS', 'surname': 'Kim'},
#         {'given-names': 'JU', 'surname': 'Yoon'},
#         {'given-names': 'JD', 'surname': 'Park'},
#         {'given-names': 'BS', 'surname': 'Choi'}],
#        'pub-id': {'#text': '17687717', '@pub-id-type': 'pmid'},
#        'source': 'Inhalation toxicology',
#        'volume': '19',
#        'year': '2007'}},
#      {'@id': 'pone.0185554.ref010',
#       'label': '10',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Differential Effects of Silver Nanoparticles and Silver Ions on Tissue Accumulation, Distribution, and Toxicity in the Sprague Dawley Rat Following Daily Oral Gavage Administration for 13 Weeks',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1093/toxsci/kfv318',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1093/toxsci/kfv318'}},
#        'etal': 'et al',
#        'fpage': '131',
#        'issue': '1',
#        'lpage': '60',
#        'name': [{'given-names': 'MD', 'surname': 'Boudreau'},
#         {'given-names': 'MS', 'surname': 'Imam'},
#         {'given-names': 'AM', 'surname': 'Paredes'},
#         {'given-names': 'MS', 'surname': 'Bryant'},
#         {'given-names': 'CK', 'surname': 'Cunningham'},
#         {'given-names': 'RP', 'surname': 'Felton'}],
#        'pub-id': {'#text': '26732888', '@pub-id-type': 'pmid'},
#        'source': 'Toxicological sciences: an official journal of the Society of Toxicology',
#        'volume': '150',
#        'year': '2016'}},
#      {'@id': 'pone.0185554.ref011',
#       'label': '11',
#       'mixed-citation': {'#text': ', , , , . . . ;:\n ; PubMed Central PMCID: PMC3577117.',
#        '@publication-type': 'journal',
#        'article-title': 'Appropriate in vitro methods for genotoxicity testing of silver nanoparticles',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.5620/eht.2013.28.e2013003',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.5620/eht.2013.28.e2013003'}},
#        'fpage': 'e2013003',
#        'name': [{'given-names': 'HR', 'surname': 'Kim'},
#         {'given-names': 'YJ', 'surname': 'Park'},
#         {'given-names': 'Y', 'surname': 'Shin da'},
#         {'given-names': 'SM', 'surname': 'Oh'},
#         {'given-names': 'KH', 'surname': 'Chung'}],
#        'pub-id': {'#text': '23440978', '@pub-id-type': 'pmid'},
#        'source': 'Environmental health and toxicology',
#        'volume': '28',
#        'year': '2013'}},
#      {'@id': 'pone.0185554.ref012',
#       'label': '12',
#       'mixed-citation': {'#text': ', , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Quantitatively profiling the dissolution and redistribution of silver nanoparticles in living rats using a knotted reactor-based differentiation scheme',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1021/ac501691z',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1021/ac501691z'}},
#        'fpage': '8267',
#        'issue': '16',
#        'lpage': '74',
#        'name': [{'given-names': 'CK', 'surname': 'Su'},
#         {'given-names': 'HT', 'surname': 'Liu'},
#         {'given-names': 'SC', 'surname': 'Hsia'},
#         {'given-names': 'YC', 'surname': 'Sun'}],
#        'pub-id': {'#text': '25025651', '@pub-id-type': 'pmid'},
#        'source': 'Analytical chemistry',
#        'volume': '86',
#        'year': '2014'}},
#      {'@id': 'pone.0185554.ref013',
#       'label': '13',
#       'mixed-citation': {'#text': ', , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Cytotoxicity and genotoxicity of silver nanoparticles in human cells',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1021/nn800596w',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1021/nn800596w'}},
#        'fpage': '279',
#        'issue': '2',
#        'lpage': '90',
#        'name': [{'given-names': 'PV', 'surname': 'AshaRani'},
#         {'given-names': 'G', 'surname': 'Low Kah Mun'},
#         {'given-names': 'MP', 'surname': 'Hande'},
#         {'given-names': 'S', 'surname': 'Valiyaveettil'}],
#        'pub-id': {'#text': '19236062', '@pub-id-type': 'pmid'},
#        'source': 'ACS nano',
#        'volume': '3',
#        'year': '2009'}},
#      {'@id': 'pone.0185554.ref014',
#       'label': '14',
#       'mixed-citation': {'#text': ', , , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Genotoxic effects of silver nanoparticles stimulated by oxidative stress in human normal bronchial epithelial (BEAS-2B) cells',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.mrgentox.2011.08.008',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.mrgentox.2011.08.008'}},
#        'fpage': '129',
#        'issue': '2',
#        'lpage': '35',
#        'name': [{'given-names': 'HR', 'surname': 'Kim'},
#         {'given-names': 'MJ', 'surname': 'Kim'},
#         {'given-names': 'SY', 'surname': 'Lee'},
#         {'given-names': 'SM', 'surname': 'Oh'},
#         {'given-names': 'KH', 'surname': 'Chung'}],
#        'pub-id': {'#text': '21945414', '@pub-id-type': 'pmid'},
#        'source': 'Mutation research',
#        'volume': '726',
#        'year': '2011'}},
#      {'@id': 'pone.0185554.ref015',
#       'label': '15',
#       'mixed-citation': {'#text': ', , , , . . . \n .',
#        '@publication-type': 'journal',
#        'article-title': 'Chromium oxide nanoparticle-induced genotoxicity and p53-dependent apoptosis in human lung alveolar cells',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1002/jat.3174',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1002/jat.3174'}},
#        'name': [{'given-names': 'VA', 'surname': 'Senapati'},
#         {'given-names': 'AK', 'surname': 'Jain'},
#         {'given-names': 'GS', 'surname': 'Gupta'},
#         {'given-names': 'AK', 'surname': 'Pandey'},
#         {'given-names': 'A', 'surname': 'Dhawan'}],
#        'pub-id': {'#text': '26086747', '@pub-id-type': 'pmid'},
#        'source': 'Journal of applied toxicology: JAT',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref016',
#       'label': '16',
#       'mixed-citation': {'#text': ', , , , . . . ;():–. .',
#        '@publication-type': 'journal',
#        'article-title': 'Cytotoxic and genotoxic effects of silver nanoparticles on primary Syrian hamster embryo (SHE) cells',
#        'fpage': '161',
#        'issue': '1',
#        'lpage': '70',
#        'name': [{'given-names': 'X', 'surname': 'Li'},
#         {'given-names': 'L', 'surname': 'Xu'},
#         {'given-names': 'A', 'surname': 'Shao'},
#         {'given-names': 'G', 'surname': 'Wu'},
#         {'given-names': 'N', 'surname': 'Hanagata'}],
#        'pub-id': {'#text': '23646712', '@pub-id-type': 'pmid'},
#        'source': 'Journal of nanoscience and nanotechnology',
#        'volume': '13',
#        'year': '2013'}},
#      {'@id': 'pone.0185554.ref017',
#       'label': '17',
#       'mixed-citation': {'#text': ', , , . . . ;:–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Death and cell cycle progression are differently conditioned by the AgNP size in osteoblast-like cells',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.tox.2016.08.020',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.tox.2016.08.020'}},
#        'fpage': '103',
#        'lpage': '15',
#        'name': [{'given-names': 'F', 'surname': 'Rosario'},
#         {'given-names': 'P', 'surname': 'Hoet'},
#         {'given-names': 'C', 'surname': 'Santos'},
#         {'given-names': 'H', 'surname': 'Oliveira'}],
#        'pub-id': {'#text': '27590928', '@pub-id-type': 'pmid'},
#        'source': 'Toxicology',
#        'volume': '368–369',
#        'year': '2016'}},
#      {'@id': 'pone.0185554.ref018',
#       'label': '18',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;:–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'The impact of silver nanoparticles on marine plankton dynamics: Dependence on coating, size and concentration',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.scitotenv.2017.06.042',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.scitotenv.2017.06.042'}},
#        'etal': 'et al',
#        'fpage': '1838',
#        'lpage': '48',
#        'name': [{'given-names': 'A', 'surname': 'Tsiola'},
#         {'given-names': 'P', 'surname': 'Pitta'},
#         {'given-names': 'AJ', 'surname': 'Callol'},
#         {'given-names': 'M', 'surname': 'Kagiorgi'},
#         {'given-names': 'I', 'surname': 'Kalantzi'},
#         {'given-names': 'K', 'surname': 'Mylona'}],
#        'pub-id': {'#text': '28628993', '@pub-id-type': 'pmid'},
#        'source': 'Sci Total Environ',
#        'volume': '601–602',
#        'year': '2017'}},
#      {'@id': 'pone.0185554.ref019',
#       'label': '19',
#       'mixed-citation': {'#text': ', , , , . . . ;():\n ; PubMed Central PMCID: PMCPMC5034003.',
#        '@publication-type': 'journal',
#        'article-title': 'Uptake of silver nanoparticles by monocytic THP-1 cells depends on particle size and presence of serum proteins',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1007/s11051-016-3595-7',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1007/s11051-016-3595-7'}},
#        'fpage': '286',
#        'issue': '9',
#        'name': [{'given-names': 'K', 'surname': 'Kettler'},
#         {'given-names': 'C', 'surname': 'Giannakou'},
#         {'given-names': 'WH', 'surname': 'de Jong'},
#         {'given-names': 'AJ', 'surname': 'Hendriks'},
#         {'given-names': 'P', 'surname': 'Krystek'}],
#        'pub-id': {'#text': '27774037', '@pub-id-type': 'pmid'},
#        'source': 'J Nanopart Res',
#        'volume': '18',
#        'year': '2016'}},
#      {'@id': 'pone.0185554.ref020',
#       'label': '20',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Bioavailability and toxicokinetics of citrate-coated silver nanoparticles in rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1007/s12272-011-0118-z',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1007/s12272-011-0118-z'}},
#        'etal': 'et al',
#        'fpage': '153',
#        'issue': '1',
#        'lpage': '8',
#        'name': [{'given-names': 'K', 'surname': 'Park'},
#         {'given-names': 'EJ', 'surname': 'Park'},
#         {'given-names': 'IK', 'surname': 'Chun'},
#         {'given-names': 'K', 'surname': 'Choi'},
#         {'given-names': 'SH', 'surname': 'Lee'},
#         {'given-names': 'J', 'surname': 'Yoon'}],
#        'pub-id': {'#text': '21468927', '@pub-id-type': 'pmid'},
#        'source': 'Archives of pharmacal research',
#        'volume': '34',
#        'year': '2011'}},
#      {'@id': 'pone.0185554.ref021',
#       'label': '21',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():\n ; PubMed Central PMCID: PMCPMC4997661.',
#        '@publication-type': 'journal',
#        'article-title': 'Impact of pulmonary exposure to gold core silver nanoparticles of different size and capping agents on cardiovascular injury',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1186/s12989-016-0159-z',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1186/s12989-016-0159-z'}},
#        'etal': 'et al',
#        'fpage': '48',
#        'issue': '1',
#        'name': [{'given-names': 'NA', 'surname': 'Holland'},
#         {'given-names': 'LC', 'surname': 'Thompson'},
#         {'given-names': 'AK', 'surname': 'Vidanapathirana'},
#         {'given-names': 'RN', 'surname': 'Urankar'},
#         {'given-names': 'RM', 'surname': 'Lust'},
#         {'given-names': 'TR', 'surname': 'Fennell'}],
#        'pub-id': {'#text': '27558113', '@pub-id-type': 'pmid'},
#        'source': 'Particle and fibre toxicology',
#        'volume': '13',
#        'year': '2016'}},
#      {'@id': 'pone.0185554.ref022',
#       'label': '22',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'An insight into silver nanoparticles bioavailability in rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1039/c4mt00200h',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1039/c4mt00200h'}},
#        'etal': 'et al',
#        'fpage': '2242',
#        'issue': '12',
#        'lpage': '9',
#        'name': [{'given-names': 'J', 'surname': 'Jimenez-Lamana'},
#         {'given-names': 'F', 'surname': 'Laborda'},
#         {'given-names': 'E', 'surname': 'Bolea'},
#         {'given-names': 'I', 'surname': 'Abad-Alvaro'},
#         {'given-names': 'JR', 'surname': 'Castillo'},
#         {'given-names': 'J', 'surname': 'Bianga'}],
#        'pub-id': {'#text': '25363792', '@pub-id-type': 'pmid'},
#        'source': 'Metallomics: integrated biometal science',
#        'volume': '6',
#        'year': '2014'}},
#      {'@id': 'pone.0185554.ref023',
#       'label': '23',
#       'mixed-citation': {'#text': '. . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Toxicokinetic differences and toxicities of silver nanoparticles and silver ions in rats after single oral administration',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1080/15287394.2013.849635',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1080/15287394.2013.849635'}},
#        'fpage': '1246',
#        'issue': '22',
#        'lpage': '60',
#        'name': {'given-names': 'K', 'surname': 'Park'},
#        'pub-id': {'#text': '24283396', '@pub-id-type': 'pmid'},
#        'source': 'Journal of toxicology and environmental health Part A',
#        'volume': '76',
#        'year': '2013'}},
#      {'@id': 'pone.0185554.ref024',
#       'label': '24',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Comparative toxicity of silicon dioxide, silver and iron oxide nanoparticles after repeated oral administration to rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1002/jat.3125',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1002/jat.3125'}},
#        'etal': 'et al',
#        'fpage': '681',
#        'issue': '6',
#        'lpage': '93',
#        'name': [{'given-names': 'JW', 'surname': 'Yun'},
#         {'given-names': 'SH', 'surname': 'Kim'},
#         {'given-names': 'JR', 'surname': 'You'},
#         {'given-names': 'WH', 'surname': 'Kim'},
#         {'given-names': 'JJ', 'surname': 'Jang'},
#         {'given-names': 'SK', 'surname': 'Min'}],
#        'pub-id': {'#text': '25752675', '@pub-id-type': 'pmid'},
#        'source': 'Journal of applied toxicology: JAT',
#        'volume': '35',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref025',
#       'label': '25',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;:\n ; PubMed Central PMCID: PMC3123173.',
#        '@publication-type': 'journal',
#        'article-title': 'Distribution of silver in rats following 28 days of repeated oral exposure to silver nanoparticles or silver acetate',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1186/1743-8977-8-18',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1186/1743-8977-8-18'}},
#        'etal': 'et al',
#        'fpage': '18',
#        'name': [{'given-names': 'K', 'surname': 'Loeschner'},
#         {'given-names': 'N', 'surname': 'Hadrup'},
#         {'given-names': 'K', 'surname': 'Qvortrup'},
#         {'given-names': 'A', 'surname': 'Larsen'},
#         {'given-names': 'X', 'surname': 'Gao'},
#         {'given-names': 'U', 'surname': 'Vogel'}],
#        'pub-id': {'#text': '21631937', '@pub-id-type': 'pmid'},
#        'source': 'Particle and fibre toxicology',
#        'volume': '8',
#        'year': '2011'}},
#      {'@id': 'pone.0185554.ref026',
#       'label': '26',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Combined repeated-dose toxicity study of silver nanoparticles with the reproduction/developmental toxicity screening test',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/17435390.2013.780108',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/17435390.2013.780108'}},
#        'etal': 'et al',
#        'fpage': '349',
#        'issue': '4',
#        'lpage': '62',
#        'name': [{'given-names': 'JS', 'surname': 'Hong'},
#         {'given-names': 'S', 'surname': 'Kim'},
#         {'given-names': 'SH', 'surname': 'Lee'},
#         {'given-names': 'E', 'surname': 'Jo'},
#         {'given-names': 'B', 'surname': 'Lee'},
#         {'given-names': 'J', 'surname': 'Yoon'}],
#        'pub-id': {'#text': '23432083', '@pub-id-type': 'pmid'},
#        'source': 'Nanotoxicology',
#        'volume': '8',
#        'year': '2014'}},
#      {'@id': 'pone.0185554.ref027',
#       'label': '27',
#       'mixed-citation': {'#text': ', , , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Effects of silver nanoparticles on rat hepatic cytochrome P450 enzyme activity',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/00498254.2012.670312',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/00498254.2012.670312'}},
#        'fpage': '854',
#        'issue': '9',
#        'lpage': '62',
#        'name': [{'given-names': 'K', 'surname': 'Kulthong'},
#         {'given-names': 'R', 'surname': 'Maniratanachote'},
#         {'given-names': 'Y', 'surname': 'Kobayashi'},
#         {'given-names': 'T', 'surname': 'Fukami'},
#         {'given-names': 'T', 'surname': 'Yokoi'}],
#        'pub-id': {'#text': '22458323', '@pub-id-type': 'pmid'},
#        'source': 'Xenobiotica; the fate of foreign compounds in biological systems',
#        'volume': '42',
#        'year': '2012'}},
#      {'@id': 'pone.0185554.ref028',
#       'label': '28',
#       'mixed-citation': {'#text': ', , , , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Assessment of orally dosed commercial silver nanoparticles on human ex vivo platelet aggregation',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/17435390.2013.788749',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/17435390.2013.788749'}},
#        'fpage': '328',
#        'issue': '3',
#        'lpage': '33',
#        'name': [{'given-names': 'KJ', 'surname': 'Smock'},
#         {'given-names': 'RL', 'surname': 'Schmidt'},
#         {'given-names': 'G', 'surname': 'Hadlock'},
#         {'given-names': 'G', 'surname': 'Stoddard'},
#         {'given-names': 'DW', 'surname': 'Grainger'},
#         {'given-names': 'MA', 'surname': 'Munger'}],
#        'pub-id': {'#text': '23517080', '@pub-id-type': 'pmid'},
#        'source': 'Nanotoxicology',
#        'volume': '8',
#        'year': '2014'}},
#      {'@id': 'pone.0185554.ref029',
#       'label': '29',
#       'mixed-citation': {'#text': ', , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Dose-dependent in-vivo toxicity assessment of silver nanoparticle in Wistar rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/15376516.2010.529184',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/15376516.2010.529184'}},
#        'fpage': '13',
#        'issue': '1',
#        'lpage': '24',
#        'name': [{'given-names': 'DK', 'surname': 'Tiwari'},
#         {'given-names': 'T', 'surname': 'Jin'},
#         {'given-names': 'J', 'surname': 'Behari'}],
#        'pub-id': {'#text': '21080782', '@pub-id-type': 'pmid'},
#        'source': 'Toxicology mechanisms and methods',
#        'volume': '21',
#        'year': '2011'}},
#      {'@id': 'pone.0185554.ref030',
#       'label': '30',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;:–.  ; PubMed Central PMCID: PMC3841295.',
#        '@publication-type': 'journal',
#        'article-title': 'Allergenicity and toxicology of inhaled silver nanoparticles in allergen-provocation mice models',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.2147/IJN.S52239',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.2147/IJN.S52239'}},
#        'etal': 'et al',
#        'fpage': '4495',
#        'lpage': '506',
#        'name': [{'given-names': 'HC', 'surname': 'Chuang'},
#         {'given-names': 'TC', 'surname': 'Hsiao'},
#         {'given-names': 'CK', 'surname': 'Wu'},
#         {'given-names': 'HH', 'surname': 'Chang'},
#         {'given-names': 'CH', 'surname': 'Lee'},
#         {'given-names': 'CC', 'surname': 'Chang'}],
#        'pub-id': {'#text': '24285922', '@pub-id-type': 'pmid'},
#        'source': 'International journal of nanomedicine',
#        'volume': '8',
#        'year': '2013'}},
#      {'@id': 'pone.0185554.ref031',
#       'label': '31',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–. 10.1007/s00709-014-0701-5. 25248758.',
#        '@publication-type': 'journal',
#        'article-title': 'Modulation of liver and kidney toxicity by herb Withania somnifera for silver nanoparticles: a novel approach for harmonizing between safety and use of nanoparticles',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1007/s00709-014-0701-5',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1007/s00709-014-0701-5'}},
#        'etal': 'et al',
#        'fpage': '547',
#        'issue': '2',
#        'lpage': '58',
#        'name': [{'given-names': 'MF', 'surname': 'Anwar'},
#         {'given-names': 'D', 'surname': 'Yadav'},
#         {'given-names': 'S', 'surname': 'Rastogi'},
#         {'given-names': 'I', 'surname': 'Arora'},
#         {'given-names': 'RK', 'surname': 'Khar'},
#         {'given-names': 'J', 'surname': 'Chander'}],
#        'pub-id': {'#text': '25248758', '@pub-id-type': 'pmid'},
#        'source': 'Protoplasma',
#        'volume': '252',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref032',
#       'label': '32',
#       'mixed-citation': {'#text': ', , . . . ;():–. .',
#        '@publication-type': 'journal',
#        'article-title': 'Catalytic properties of silica/silver nanocomposites',
#        'fpage': '1968',
#        'issue': '7',
#        'lpage': '72',
#        'name': [{'given-names': 'HJ', 'surname': 'Zhai'},
#         {'given-names': 'DW', 'surname': 'Sun'},
#         {'given-names': 'HS', 'surname': 'Wang'}],
#        'pub-id': {'#text': '17025110', '@pub-id-type': 'pmid'},
#        'source': 'Journal of nanoscience and nanotechnology',
#        'volume': '6',
#        'year': '2006'}},
#      {'@id': 'pone.0185554.ref033',
#       'label': '33',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–. .',
#        '@publication-type': 'journal',
#        'article-title': 'Neurotoxicity of Silver Nanoparticles in Rat Brain After Intragastric Exposure',
#        'etal': 'et al',
#        'fpage': '4215',
#        'issue': '6',
#        'lpage': '23',
#        'name': [{'given-names': 'L', 'surname': 'Xu'},
#         {'given-names': 'A', 'surname': 'Shao'},
#         {'given-names': 'Y', 'surname': 'Zhao'},
#         {'given-names': 'Z', 'surname': 'Wang'},
#         {'given-names': 'C', 'surname': 'Zhang'},
#         {'given-names': 'Y', 'surname': 'Sun'}],
#        'pub-id': {'#text': '26369032', '@pub-id-type': 'pmid'},
#        'source': 'Journal of nanoscience and nanotechnology',
#        'volume': '15',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref034',
#       'label': '34',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;:\n ; PubMed Central PMCID: PMCPMC4772516.',
#        '@publication-type': 'journal',
#        'article-title': 'Tissue distribution and acute toxicity of silver after single intravenous administration in mice: nano-specific and size-dependent effects',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1186/s12989-016-0124-x',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1186/s12989-016-0124-x'}},
#        'etal': 'et al',
#        'fpage': '12',
#        'name': [{'given-names': 'C', 'surname': 'Recordati'},
#         {'given-names': 'M', 'surname': 'De Maglie'},
#         {'given-names': 'S', 'surname': 'Bianchessi'},
#         {'given-names': 'S', 'surname': 'Argentiere'},
#         {'given-names': 'C', 'surname': 'Cella'},
#         {'given-names': 'S', 'surname': 'Mattiello'}],
#        'pub-id': {'#text': '26926244', '@pub-id-type': 'pmid'},
#        'source': 'Particle and fibre toxicology',
#        'volume': '13',
#        'year': '2016'}},
#      {'@id': 'pone.0185554.ref035',
#       'label': '35',
#       'mixed-citation': {'#text': ', , , , , . . . :–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'The acute toxic effects of silver nanoparticles on myocardial transmembrane potential, INa and IK1 channels and heart rhythm in mice',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1080/17435390.2017.1367047',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1080/17435390.2017.1367047'}},
#        'fpage': '1',
#        'lpage': '11',
#        'name': [{'given-names': 'CX', 'surname': 'Lin'},
#         {'given-names': 'SY', 'surname': 'Yang'},
#         {'given-names': 'JL', 'surname': 'Gu'},
#         {'given-names': 'J', 'surname': 'Meng'},
#         {'given-names': 'HY', 'surname': 'Xu'},
#         {'given-names': 'JM', 'surname': 'Cao'}],
#        'pub-id': {'#text': '28830271', '@pub-id-type': 'pmid'},
#        'source': 'Nanotoxicology',
#        'volume': '2017'}},
#      {'@id': 'pone.0185554.ref036',
#       'label': '36',
#       'mixed-citation': {'#text': ', , , , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Free silver ion as the main cause of acute and chronic toxicity of silver nanoparticles to cladocerans',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1007/s00244-014-0091-x',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1007/s00244-014-0091-x'}},
#        'fpage': '500',
#        'issue': '3',
#        'lpage': '9',
#        'name': [{'given-names': 'M', 'surname': 'Sakamoto'},
#         {'given-names': 'JY', 'surname': 'Ha'},
#         {'given-names': 'S', 'surname': 'Yoneshima'},
#         {'given-names': 'C', 'surname': 'Kataoka'},
#         {'given-names': 'H', 'surname': 'Tatsuta'},
#         {'given-names': 'S', 'surname': 'Kashiwada'}],
#        'pub-id': {'#text': '25352442', '@pub-id-type': 'pmid'},
#        'source': 'Archives of environmental contamination and toxicology',
#        'volume': '68',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref037',
#       'label': '37',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Subacute oral toxicity investigation of nanoparticulate and ionic silver in rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1007/s00204-011-0759-1',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1007/s00204-011-0759-1'}},
#        'etal': 'et al',
#        'fpage': '543',
#        'issue': '4',
#        'lpage': '51',
#        'name': [{'given-names': 'N', 'surname': 'Hadrup'},
#         {'given-names': 'K', 'surname': 'Loeschner'},
#         {'given-names': 'A', 'surname': 'Bergstrom'},
#         {'given-names': 'A', 'surname': 'Wilcks'},
#         {'given-names': 'X', 'surname': 'Gao'},
#         {'given-names': 'U', 'surname': 'Vogel'}],
#        'pub-id': {'#text': '21969074', '@pub-id-type': 'pmid'},
#        'source': 'Archives of toxicology',
#        'volume': '86',
#        'year': '2012'}},
#      {'@id': 'pone.0185554.ref038',
#       'label': '38',
#       'mixed-citation': {'#text': ', , , . . . ;():\n ; PubMed Central PMCID: PMC4465040.',
#        '@publication-type': 'journal',
#        'article-title': 'Mechanisms of Toxicity of Ag Nanoparticles in Comparison to Bulk and Ionic Ag on Mussel Hemocytes and Gill Cells',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1371/journal.pone.0129039',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1371/journal.pone.0129039'}},
#        'fpage': 'e0129039',
#        'issue': '6',
#        'name': [{'given-names': 'A', 'surname': 'Katsumiti'},
#         {'given-names': 'D', 'surname': 'Gilliland'},
#         {'given-names': 'I', 'surname': 'Arostegui'},
#         {'given-names': 'MP', 'surname': 'Cajaraville'}],
#        'pub-id': {'#text': '26061169', '@pub-id-type': 'pmid'},
#        'source': 'PloS one',
#        'volume': '10',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref039',
#       'label': '39',
#       'mixed-citation': {'#text': ', , , , . . . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Negligible particle-specific antibacterial activity of silver nanoparticles',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1021/nl301934w',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1021/nl301934w'}},
#        'fpage': '4271',
#        'issue': '8',
#        'lpage': '5',
#        'name': [{'given-names': 'ZM', 'surname': 'Xiu'},
#         {'given-names': 'QB', 'surname': 'Zhang'},
#         {'given-names': 'HL', 'surname': 'Puppala'},
#         {'given-names': 'VL', 'surname': 'Colvin'},
#         {'given-names': 'PJ', 'surname': 'Alvarez'}],
#        'pub-id': {'#text': '22765771', '@pub-id-type': 'pmid'},
#        'source': 'Nano Lett',
#        'volume': '12',
#        'year': '2012'}},
#      {'@id': 'pone.0185554.ref040',
#       'label': '40',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Negligible particle-specific toxicity mechanism of silver nanoparticles: the role of Ag+ ion release in the cytosol',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.nano.2014.11.002',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.nano.2014.11.002'}},
#        'etal': 'et al',
#        'fpage': '731',
#        'issue': '3',
#        'lpage': '9',
#        'name': [{'given-names': 'V', 'surname': 'De Matteis'},
#         {'given-names': 'MA', 'surname': 'Malvindi'},
#         {'given-names': 'A', 'surname': 'Galeone'},
#         {'given-names': 'V', 'surname': 'Brunetti'},
#         {'given-names': 'E', 'surname': 'De Luca'},
#         {'given-names': 'S', 'surname': 'Kote'}],
#        'pub-id': {'#text': '25546848', '@pub-id-type': 'pmid'},
#        'source': 'Nanomedicine',
#        'volume': '11',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref041',
#       'label': '41',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  ; PubMed Central PMCID: PMCPMC4120234.',
#        '@publication-type': 'journal',
#        'article-title': 'A general mechanism for intracellular toxicity of metal-containing nanoparticles',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1039/c4nr01234h',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1039/c4nr01234h'}},
#        'etal': 'et al',
#        'fpage': '7052',
#        'issue': '12',
#        'lpage': '61',
#        'name': [{'given-names': 'S', 'surname': 'Sabella'},
#         {'given-names': 'RP', 'surname': 'Carney'},
#         {'given-names': 'V', 'surname': 'Brunetti'},
#         {'given-names': 'MA', 'surname': 'Malvindi'},
#         {'given-names': 'N', 'surname': 'Al-Juffali'},
#         {'given-names': 'G', 'surname': 'Vecchio'}],
#        'pub-id': {'#text': '24842463', '@pub-id-type': 'pmid'},
#        'source': 'Nanoscale',
#        'volume': '6',
#        'year': '2014'}},
#      {'@id': 'pone.0185554.ref042',
#       'label': '42',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Toxic responses in rat embryonic cells to silver nanoparticles and released silver ions as analyzed via gene expression profiles and transmission electron microscopy',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.3109/17435390.2014.948942',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.3109/17435390.2014.948942'}},
#        'etal': 'et al',
#        'fpage': '513',
#        'issue': '4',
#        'lpage': '22',
#        'name': [{'given-names': 'L', 'surname': 'Xu'},
#         {'given-names': 'C', 'surname': 'Shi'},
#         {'given-names': 'A', 'surname': 'Shao'},
#         {'given-names': 'X', 'surname': 'Li'},
#         {'given-names': 'X', 'surname': 'Cheng'},
#         {'given-names': 'R', 'surname': 'Ding'}],
#        'pub-id': {'#text': '25119417', '@pub-id-type': 'pmid'},
#        'source': 'Nanotoxicology',
#        'volume': '9',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref043',
#       'label': '43',
#       'mixed-citation': {'#text': ', , , . . \n;():.',
#        '@publication-type': 'journal',
#        'article-title': 'Nanotoxicity and spectroscopy studies of silver nanoparticle: calf thymus DNA and k562 as targets',
#        'fpage': '7',
#        'issue': '13',
#        'name': [{'given-names': 'M', 'surname': 'Rahban'},
#         {'given-names': 'A', 'surname': 'Divsalar'},
#         {'given-names': 'AA', 'surname': 'Saboury'},
#         {'given-names': 'A', 'surname': 'Golestani'}],
#        'source': 'J Phys Chem C',
#        'volume': '114',
#        'year': '2010'}},
#      {'@id': 'pone.0185554.ref044',
#       'label': '44',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Silver nanoparticles induce oxidative cell damage in human liver cells through inhibition of reduced glutathione and induction of mitochondria-involved apoptosis',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.toxlet.2010.12.010',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.toxlet.2010.12.010'}},
#        'etal': 'et al',
#        'fpage': '92',
#        'issue': '1',
#        'lpage': '100',
#        'name': [{'given-names': 'MJ', 'surname': 'Piao'},
#         {'given-names': 'KA', 'surname': 'Kang'},
#         {'given-names': 'IK', 'surname': 'Lee'},
#         {'given-names': 'HS', 'surname': 'Kim'},
#         {'given-names': 'S', 'surname': 'Kim'},
#         {'given-names': 'JY', 'surname': 'Choi'}],
#        'pub-id': {'#text': '21182908', '@pub-id-type': 'pmid'},
#        'source': 'Toxicology letters',
#        'volume': '201',
#        'year': '2011'}},
#      {'@id': 'pone.0185554.ref045',
#       'label': '45',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  ; PubMed Central PMCID: PMC4526150.',
#        '@publication-type': 'journal',
#        'article-title': 'Silver nanospheres are cytotoxic and genotoxic to fish cells',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.aquatox.2009.11.016',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.aquatox.2009.11.016'}},
#        'etal': 'et al',
#        'fpage': '34',
#        'issue': '1',
#        'lpage': '41',
#        'name': [{'given-names': 'JP', 'suffix': 'Sr.', 'surname': 'Wise'},
#         {'given-names': 'BC', 'surname': 'Goodale'},
#         {'given-names': 'SS', 'surname': 'Wise'},
#         {'given-names': 'GA', 'surname': 'Craig'},
#         {'given-names': 'AF', 'surname': 'Pongan'},
#         {'given-names': 'RB', 'surname': 'Walter'}],
#        'pub-id': {'#text': '20060603', '@pub-id-type': 'pmid'},
#        'source': 'Aquatic toxicology',
#        'volume': '97',
#        'year': '2010'}},
#      {'@id': 'pone.0185554.ref046',
#       'label': '46',
#       'mixed-citation': {'#text': ', , , , , , \n. . ;():–.  ; PubMed Central PMCID: PMC4362240.',
#        '@publication-type': 'journal',
#        'article-title': 'Oxidative stress promotes pathologic polyploidization in nonalcoholic fatty liver disease',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1172/JCI73957',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1172/JCI73957'}},
#        'etal': 'et al',
#        'fpage': '981',
#        'issue': '3',
#        'lpage': '92',
#        'name': [{'given-names': 'G', 'surname': 'Gentric'},
#         {'given-names': 'V', 'surname': 'Maillet'},
#         {'given-names': 'V', 'surname': 'Paradis'},
#         {'given-names': 'D', 'surname': 'Couton'},
#         {'given-names': 'A', 'surname': "L'Hermitte"},
#         {'given-names': 'G', 'surname': 'Panasyuk'}],
#        'pub-id': {'#text': '25621497', '@pub-id-type': 'pmid'},
#        'source': 'The Journal of clinical investigation',
#        'volume': '125',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref047',
#       'label': '47',
#       'mixed-citation': {'#text': ', , . . . \n .',
#        '@publication-type': 'journal',
#        'article-title': 'Genotoxicity study of silver nanoparticles in bone marrow cells of Sprague-Dawley rats',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.fct.2015.05.005',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.fct.2015.05.005'}},
#        'name': [{'given-names': 'AK', 'surname': 'Patlolla'},
#         {'given-names': 'D', 'surname': 'Hackett'},
#         {'given-names': 'PB', 'surname': 'Tchounwou'}],
#        'pub-id': {'#text': '26032631', '@pub-id-type': 'pmid'},
#        'source': 'Food and chemical toxicology: an international journal published for the British Industrial Biological Research Association',
#        'year': '2015'}},
#      {'@id': 'pone.0185554.ref048',
#       'label': '48',
#       'mixed-citation': {'#text': ', , . . . ;:–.  .',
#        '@publication-type': 'journal',
#        'article-title': 'Cytidine-stabilized gold nanocluster as a fluorescence turn-on and turn-off probe for dual functional detection of Ag(+) and Hg(2+)',
#        'comment': {'#text': 'doi:',
#         'ext-link': {'#text': '10.1016/j.aca.2015.01.016',
#          '@ext-link-type': 'uri',
#          '@xlink:href': 'https://doi.org/10.1016/j.aca.2015.01.016'}},
#        'fpage': '1',
#        'lpage': '7',
#        'name': [{'given-names': 'Y', 'surname': 'Zhang'},
#         {'given-names': 'H', 'surname': 'Jiang'},
#         {'given-names': 'X', 'surname': 'Wang'}],
#        'pub-id': {'#text': '25819783', '@pub-id-type': 'pmid'},
#        'source': 'Analytica chimica acta',
#        'volume': '870',
#        'year': '2015'}}],
#     'title': 'References'}},
#   'body': {'sec': [{'@id': 'sec005',
#      '@sec-type': 'intro',
# ...
#         'caption': {'p': 'Click here for additional data file.'}}}],
#      'title': 'Supporting information'}]},
#   'front': {'article-meta': {'abstract': {'sec': [{'@id': 'sec001',
#        'p': 'The potential risk of a nanoparticle as a medical application has raised wide concerns, and this study aims to investigate silver nanoparticle (AgNP)-induced acute toxicities, genotoxicities, target organs and the underlying mechanisms.',
#        'title': 'Objective'},
#       {'@id': 'sec002',
#        'p': {'#text': 'rats were randomly divided into 4 groups ( = 4 each group), and AgNP (containing Ag nanoparticles and released Ag, 5 mg/kg), Ag (released from the same dose of AgNP, 0.0003 mg/kg), 5% sucrose solution (vechicle control) and cyclophophamide (positive control, 40 mg/kg) were administrated intravenously for 24 h respectively. Clinical signs and body weight of rats were recorded, and the tissues were subsequently collected for biochemical examination, Ag distribution detection, histopathological examination and genotoxicity assays.',
#         'italic': ['Sprague-Dawley', 'n'],
#         'sup': ['+', '+', '+']},
#        'title': 'Methods'},
#       {'@id': 'sec003',
#        'p': {'#text': 'The rank of Ag detected in organs from highest to lowest is lung>spleen>liver>kidney>thymus>heart. Administration of AgNP induced a marked increase of ALT, BUN, TBil and Cre. Histopathological examination results showed that AgNP induced more extensive organ damages in liver, kidneys, thymus, and spleen. Bone marrow micronucleus assay found no statistical significance among groups ( > 0.05), but the number of aberration cells and multiple aberration cells were predominately increased from rats dosed with Ag and AgNP ( < 0.01), and more polyploidy cells were generated in the AgNP group (4.3%) compared with control.',
#         'italic': ['p', 'p'],
#         'sup': '+'},
#        'title': 'Results'},
#       {'@id': 'sec004',
#        'p': {'#text': 'Our results indicated that the AgNP accumulated in the immune system organs, and mild irritation was observed in the thymus and spleen of animals treated with AgNP, but not with Ag. The liver and kidneys could be the most affected organs by an acute .. dose of AgNP, and significantly increased chromosome breakage and polyploidy cell rates also implied the potential genotoxicity of AgNP. However, particle-specific toxicities and potential carcinogenic effect remain to be further confirmed in a chronic toxicity study.',
#         'italic': ['i', 'v'],
#         'sup': '+'},
#        'title': 'Conclusion'}]},
#     'aff': [{'@id': 'aff001',
#       'addr-line': 'National Center for Safety Evaluation of Drugs, National Institutes for Food and Drug Control, Key Laboratory of Beijing for Nonclinical Safety Evaluation Research of Drugs, Beijing, P.R., China',
#       'label': '1'},
#      {'@id': 'aff002',
#       'addr-line': 'Institute for Medical Device Control, National Institutes for Food and Drug Control, Beijing, P. R., China',
#       'label': '2'},
#      {'@id': 'aff003',
#       'addr-line': 'Key Lab of Advanced Technologies of Materials, Ministry of Education, School of Materials Science and Engineering, Southwest Jiaotong University, Chengdu, China',
#       'label': '3'},
#      {'@id': 'edit1', 'addr-line': 'Brandeis University, UNITED STATES'}],
#     'article-categories': {'subj-group': [{'@subj-group-type': 'heading',
#        'subject': 'Research Article'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subject': 'Toxicity'},
#         'subject': 'Toxicology'},
#        'subject': 'Biology and Life Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Toxicity'},
#          'subject': 'Toxicology'},
#         'subject': 'Pathology and Laboratory Medicine'},
#        'subject': 'Medicine and Health Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Spleen'},
#          'subject': 'Immune Physiology'},
#         'subject': 'Physiology'},
#        'subject': 'Biology and Life Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Spleen'},
#          'subject': 'Immune Physiology'},
#         'subject': 'Physiology'},
#        'subject': 'Medicine and Health Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subject': 'Liver'},
#         'subject': 'Anatomy'},
#        'subject': 'Biology and Life Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subject': 'Liver'},
#         'subject': 'Anatomy'},
#        'subject': 'Medicine and Health Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Kidneys'},
#          'subject': 'Renal System'},
#         'subject': 'Anatomy'},
#        'subject': 'Biology and Life Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Kidneys'},
#          'subject': 'Renal System'},
#         'subject': 'Anatomy'},
#        'subject': 'Medicine and Health Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subject': 'Nanoparticles'},
#         'subject': 'Nanotechnology'},
#        'subject': 'Engineering and Technology'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Thymus'},
#          'subject': 'Immune System'},
#         'subject': 'Immunology'},
#        'subject': 'Biology and Life Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Thymus'},
#          'subject': 'Immune System'},
#         'subject': 'Immunology'},
#        'subject': 'Medicine and Health Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subject': 'Micronuclei'},
#          'subject': 'Protozoology'},
#         'subject': 'Microbiology'},
#        'subject': 'Biology and Life Sciences'},
#       {'@subj-group-type': 'Discipline-v3',
#        'subj-group': {'subj-group': {'subj-group': {'subj-group': {'subject': 'Bone Marrow Cells'},
#           'subject': 'Animal Cells'},
#          'subject': 'Cellular Types'},
#         'subject': 'Cell Biology'},
#        'subject': 'Biology and Life Sciences'}]},
#     'article-id': [{'#text': '28953974', '@pub-id-type': 'pmid'},
#      {'#text': '5617228', '@pub-id-type': 'pmc'},
#      {'#text': '10.1371/journal.pone.0185554', '@pub-id-type': 'doi'},
#      {'#text': 'PONE-D-17-09495', '@pub-id-type': 'publisher-id'}],
#     'author-notes': {'corresp': {'#text': '* E-mail:',
#       '@id': 'cor001',
#       'email': 'xuliming@nifdc.org.cn'},
#      'fn': {'@fn-type': 'COI-statement',
#       '@id': 'coi001',
#       'p': {'#text': 'The authors have declared that no competing interests exist.',
#        'bold': 'Competing Interests:'}}},
#     'contrib-group': [{'contrib': [{'@contrib-type': 'author',
#         '@equal-contrib': 'yes',
#         'name': {'given-names': 'Hairuo', 'surname': 'Wen'},
#         'role': [{'#text': 'Conceptualization',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Data curation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Formal analysis',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Methodology',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Project administration',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Visualization',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Writing – original draft',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Writing – review & editing',
#           '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff001', 'sup': '1'}},
#        {'@contrib-type': 'author',
#         '@equal-contrib': 'yes',
#         'name': {'given-names': 'Mo', 'surname': 'Dan'},
#         'role': [{'#text': 'Conceptualization',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Data curation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Formal analysis',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Funding acquisition',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Methodology',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Writing – original draft',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Writing – review & editing',
#           '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff001', 'sup': '1'}},
#        {'@contrib-type': 'author',
#         'name': {'given-names': 'Ying', 'surname': 'Yang'},
#         'role': [{'#text': 'Data curation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Formal analysis',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff001', 'sup': '1'}},
#        {'@contrib-type': 'author',
#         'name': {'given-names': 'Jianjun', 'surname': 'Lyu'},
#         'role': [{'#text': 'Data curation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Formal analysis',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff001', 'sup': '1'}},
#        {'@contrib-type': 'author',
#         'name': {'given-names': 'Anliang', 'surname': 'Shao'},
#         'role': [{'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Resources', '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff002', 'sup': '2'}},
#        {'@contrib-type': 'author',
#         'name': {'given-names': 'Xiang', 'surname': 'Cheng'},
#         'role': [{'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Methodology',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Resources', '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff003', 'sup': '3'}},
#        {'@contrib-type': 'author',
#         'name': {'given-names': 'Liang', 'surname': 'Chen'},
#         'role': [{'#text': 'Investigation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Methodology',
#           '@content-type': 'http://credit.casrai.org/'}],
#         'xref': {'@ref-type': 'aff', '@rid': 'aff002', 'sup': '2'}},
#        {'@contrib-type': 'author',
#         'contrib-id': {'#text': 'http://orcid.org/0000-0003-2365-8000',
#          '@authenticated': 'true',
#          '@contrib-id-type': 'orcid'},
#         'name': {'given-names': 'Liming', 'surname': 'Xu'},
#         'role': [{'#text': 'Conceptualization',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Data curation',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Funding acquisition',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Project administration',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Supervision',
#           '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Validation', '@content-type': 'http://credit.casrai.org/'},
#          {'#text': 'Writing – review & editing',
#           '@content-type': 'http://credit.casrai.org/'}],
#         'xref': [{'@ref-type': 'aff', '@rid': 'aff002', 'sup': '2'},
#          {'#text': '*', '@ref-type': 'corresp', '@rid': 'cor001'}]}]},
#      {'contrib': {'@contrib-type': 'editor',
#        'name': {'given-names': 'Bing', 'surname': 'Xu'},
#        'role': 'Editor',
#        'xref': {'@ref-type': 'aff', '@rid': 'edit1'}}}],
#     'counts': {'fig-count': {'@count': '5'},
#      'page-count': {'@count': '16'},
#      'table-count': {'@count': '3'}},
#     'custom-meta-group': {'custom-meta': {'@id': 'data-availability',
#       'meta-name': 'Data Availability',
#       'meta-value': 'All relevant data are within the paper and its Supporting Information files.'}},
#     'elocation-id': 'e0185554',
#     'funding-group': {'award-group': [{'@id': 'award001',
#        'award-id': '2016YFA0200903',
#        'funding-source': {'institution': 'National Key Research and Development Program of China'},
#        'principal-award-recipient': {'contrib-id': {'#text': 'http://orcid.org/0000-0003-2365-8000',
#          '@authenticated': 'true',
#          '@contrib-id-type': 'orcid'},
#         'name': {'given-names': 'Liming', 'surname': 'Xu'}}},
#       {'@id': 'award002',
#        'award-id': '81401517',
#        'funding-source': {'institution': 'National Science Foundation'},
#        'principal-award-recipient': {'name': {'given-names': 'Mo',
#          'surname': 'Dan'}}}],
#      'funding-statement': {'#text': 'Financial support was received from National Key Research and Development Program of China (Grant No. 2016YFA0200903) () and the National Science Foundation (Grant No. 81401517) (). The funders had no role in study design, data collection and analysis, decision to publish, or preparation of the manuscript.',
#       'ext-link': [{'#text': 'http://www.most.gov.cn/',
#         '@ext-link-type': 'uri',
#         '@xlink:href': 'http://www.most.gov.cn/'},
#        {'#text': 'http://www.nsfc.gov.cn/',
#         '@ext-link-type': 'uri',
#         '@xlink:href': 'http://www.nsfc.gov.cn/'}]}},
#     'history': {'date': [{'@date-type': 'received',
#        'day': '3',
#        'month': '5',
#        'year': '2017'},
#       {'@date-type': 'accepted', 'day': '14', 'month': '9', 'year': '2017'}]},
#     'issue': '9',
#     'permissions': {'copyright-holder': 'Wen et al',
#      'copyright-statement': '© 2017 Wen et al',
#      'copyright-year': '2017',
#      'license': {'@xlink:href': 'http://creativecommons.org/licenses/by/4.0/',
#       'license-p': {'#text': 'This is an open access article distributed under the terms of the , which permits unrestricted use, distribution, and reproduction in any medium, provided the original author and source are credited.',
#        'ext-link': {'#text': 'Creative Commons Attribution License',
#         '@ext-link-type': 'uri',
#         '@xlink:href': 'http://creativecommons.org/licenses/by/4.0/'}}}},
#     'pub-date': [{'@pub-type': 'epub',
#       'day': '27',
#       'month': '9',
#       'year': '2017'},
#      {'@pub-type': 'collection', 'year': '2017'}],
#     'self-uri': {'@content-type': 'pdf', '@xlink:href': 'pone.0185554.pdf'},
#     'title-group': {'alt-title': {'#text': 'Acute toxicity and genotoxicity of silver nanoparticle',
#       '@alt-title-type': 'running-head'},
#      'article-title': 'Acute toxicity and genotoxicity of silver nanoparticle in rats'},
#     'volume': '12'},
#    'journal-meta': {'issn': {'#text': '1932-6203', '@pub-type': 'epub'},
#     'journal-id': [{'#text': 'PLoS One', '@journal-id-type': 'nlm-ta'},
#      {'#text': 'PLoS ONE', '@journal-id-type': 'iso-abbrev'},
#      {'#text': 'plos', '@journal-id-type': 'publisher-id'},
#      {'#text': 'plosone', '@journal-id-type': 'pmc'}],
#     'journal-title-group': {'journal-title': 'PLoS ONE'},
#     'publisher': {'publisher-loc': 'San Francisco, CA USA',
#      'publisher-name': 'Public Library of Science'}},
#    'notes': {'p': 'All relevant data are within the paper and its Supporting Information files.',
#     'title': 'Data Availability'}}}}
