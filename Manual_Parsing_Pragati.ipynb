# %%
import os 
from bson import json_util
from pymongo import MongoClient
import json
import xmltodict
from collections import defaultdict
import xml.etree.ElementTree as ET

client = MongoClient('mongodb://jmp3mk:Zlo2bLgAgoR3V6Pq@cluster0-shard-00-00-dsbst.mongodb.net:27017,cluster0-shard-00-01-dsbst.mongodb.net:27017,cluster0-shard-00-02-dsbst.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')
path = 'C:/Users/Pragati Shah/sample from corpus/journal.pbio.0000001.xml'

# %%
tree = ET.parse(path)  
root = tree.getroot()                    
root
# Out:
# <Element 'article' at 0x000002077CB57C28>

# %%
root.tag
# Out:
# 'article'

# %%
root.attrib
# Out:
# {'article-type': 'research-article',
#  'dtd-version': '3.0',
#  '{http://www.w3.org/XML/1998/namespace}lang': 'EN'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# front {}
# body {}
# back {}

# %%
for child_of_root in root:
    print(child_of_root.tag, child_of_root.attrib)
# Out:
# front {}
# body {}
# back {}

# %%
 for elem in tree.iter():
        print (elem.tag, elem.attrib)
# Out:
# article {'article-type': 'research-article', 'dtd-version': '3.0', '{http://www.w3.org/XML/1998/namespace}lang': 'EN'}
# front {}
# journal-meta {}
# journal-id {'journal-id-type': 'publisher-id'}
# journal-id {'journal-id-type': 'publisher'}
# journal-id {'journal-id-type': 'nlm-ta'}
# journal-id {'journal-id-type': 'pmc'}
# journal-title-group {}
# journal-title {}
# issn {'pub-type': 'ppub'}
# issn {'pub-type': 'epub'}
# publisher {}
# publisher-name {}
# publisher-loc {}
# article-meta {}
# article-id {'pub-id-type': 'doi'}
# article-categories {}
# subj-group {'subj-group-type': 'heading'}
# subject {}
# subj-group {'subj-group-type': 'Discipline'}
# subject {}
# subject {}
# subject {}
# subj-group {'subj-group-type': 'System Taxonomy'}
# subject {}
# subject {}
# title-group {}
# article-title {}
# alt-title {'alt-title-type': 'running-head'}
# contrib-group {}
# contrib {'contrib-type': 'author', 'equal-contrib': 'yes', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# xref {'ref-type': 'aff', 'rid': 'aff1'}
# sup {}
# contrib {'contrib-type': 'author', 'equal-contrib': 'yes', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# xref {'ref-type': 'aff', 'rid': 'aff1'}
# sup {}
# contrib {'contrib-type': 'author', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# xref {'ref-type': 'aff', 'rid': 'aff2'}
# sup {}
# contrib {'contrib-type': 'author', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# xref {'ref-type': 'aff', 'rid': 'aff3'}
# sup {}
# contrib {'contrib-type': 'author', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# xref {'ref-type': 'aff', 'rid': 'aff2'}
# sup {}
# contrib {'contrib-type': 'author', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# xref {'ref-type': 'aff', 'rid': 'aff1'}
# sup {}
# xref {'ref-type': 'corresp', 'rid': 'cor1'}
# sup {}
# aff {'id': 'aff1'}
# label {}
# addr-line {}
# aff {'id': 'aff2'}
# label {}
# addr-line {}
# aff {'id': 'aff3'}
# label {}
# addr-line {}
# contrib-group {}
# contrib {'contrib-type': 'editor', '{http://www.w3.org/1999/xlink}type': 'simple'}
# name {'name-style': 'western'}
# surname {}
# role {}
# xref {'ref-type': 'aff', 'rid': 'edit1'}
# aff {'id': 'edit1'}
# author-notes {}
# corresp {'id': 'cor1'}
# email {'{http://www.w3.org/1999/xlink}type': 'simple'}
# fn {'fn-type': 'con', 'id': 'n2'}
# p {}
# fn {'fn-type': 'conflict', 'id': 'n1'}
# p {}
# pub-date {'pub-type': 'ppub'}
# month {}
# year {}
# pub-date {'pub-type': 'epub'}
# day {}
# month {}
# year {}
# volume {}
# issue {}
# elocation-id {}
# history {}
# date {'date-type': 'received'}
# day {}
# month {}
# year {}
# date {'date-type': 'accepted'}
# day {}
# month {}
# year {}
# permissions {}
# copyright-year {}
# copyright-holder {}
# license {}
# license-p {}
# related-article {'page': 'e16', 'related-article-type': 'companion', 'vol': '1', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000016', '{http://www.w3.org/1999/xlink}title': 'primer', '{http://www.w3.org/1999/xlink}type': 'simple'}
# article-title {}
# related-article {'page': 'e4', 'related-article-type': 'companion', 'vol': '1', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000004', '{http://www.w3.org/1999/xlink}title': 'synopsis', '{http://www.w3.org/1999/xlink}type': 'simple'}
# article-title {}
# abstract {}
# p {}
# abstract {'abstract-type': 'toc'}
# p {}
# body {}
# sec {'id': 's1'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fugmann2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hesslein1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fugmann2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Jones1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Mundy1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hiom2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Bassing1'}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tonegawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akira1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Roth1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Difilippantonio1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Spanopoulou1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Nagawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tonegawa1'}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tonegawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akira1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hesse2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tonegawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hesse2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Suzuki1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Connor1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Larijani1'}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tonegawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hesse2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akira1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Wei1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fanning1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Nadel1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Larijani1'}
# p {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akira1'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# fig {'id': 'pbio-0000001-g001', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g001', '{http://www.w3.org/1999/xlink}type': 'simple'}
# sec {'id': 's2'}
# title {}
# sec {'id': 's2a'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# italic {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Livak2'}
# fig {'id': 'pbio-0000001-g002', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g002', '{http://www.w3.org/1999/xlink}type': 'simple'}
# sec {'id': 's2b'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# sec {'id': 's2c'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g003'}
# fig {'id': 'pbio-0000001-g003', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# p {}
# p {}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g003', '{http://www.w3.org/1999/xlink}type': 'simple'}
# sec {'id': 's2d'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g003'}
# sec {'id': 's2e'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Steen1'}
# fig {'id': 'pbio-0000001-g004', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# p {}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g004', '{http://www.w3.org/1999/xlink}type': 'simple'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# sec {'id': 's2f'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hiom1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson2'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g005'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g005'}
# fig {'id': 'pbio-0000001-g005', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# p {}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g005', '{http://www.w3.org/1999/xlink}type': 'simple'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g005'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g004'}
# p {}
# sec {'id': 's2g'}
# title {}
# p {}
# p {}
# italic {}
# italic {}
# italic {}
# italic {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g006'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g006'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fanning1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Larijani1'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g006'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# fig {'id': 'pbio-0000001-g006', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# bold {}
# sup {}
# bold {}
# sub {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g006', '{http://www.w3.org/1999/xlink}type': 'simple'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g006'}
# sec {'id': 's2h'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Cowell1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Cowell2'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g007'}
# italic {}
# sub {}
# italic {}
# sub {}
# italic {}
# sub {}
# fig {'id': 'pbio-0000001-g007', 'position': 'float'}
# object-id {'pub-id-type': 'doi'}
# label {}
# caption {}
# title {}
# p {}
# graphic {'mimetype': 'image', 'position': 'float', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.g007', '{http://www.w3.org/1999/xlink}type': 'simple'}
# p {}
# italic {}
# sec {'id': 's3'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Livak1'}
# sec {'id': 's3a'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tonegawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hesse2'}
# sec {'id': 's3b'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g001'}
# italic {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Feng1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Spanopoulou1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Nagawa1'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g003'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Gorin1'}
# sec {'id': 's3c'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hiom1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g005'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g005'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g002'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g006'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Nagawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson1'}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hiom2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-West1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Jung1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Jung1'}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hiom2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Tsai1'}
# sec {'id': 's3d'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Ramsden2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fanning1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Nadel1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akira1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Wei1'}
# sec {'id': 's3e'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Eastman2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Mo1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson3'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Akamatsu1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Nagawa1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Swanson1'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g006'}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g007'}
# italic {}
# italic {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Argast1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Jurica1'}
# italic {}
# italic {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Travers1'}
# p {}
# sub {}
# sub {}
# p {}
# sec {'id': 's3f'}
# title {}
# p {}
# xref {'ref-type': 'fig', 'rid': 'pbio-0000001-g007'}
# p {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Cowell1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Cowell2'}
# sec {'id': 's4'}
# title {}
# sec {'id': 's4a'}
# title {}
# sec {'id': 's4a1'}
# title {}
# p {}
# xref {'ref-type': 'supplementary-material', 'rid': 'st001'}
# xref {'ref-type': 'supplementary-material', 'rid': 'st002'}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Eastman1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Leu1'}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fugmann1'}
# italic {}
# italic {}
# xref {'ref-type': 'supplementary-material', 'rid': 'st001'}
# p {}
# italic {}
# italic {}
# italic {}
# italic {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Roman1'}
# sec {'id': 's4a2'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fugmann1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Hesse1'}
# sub {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# sec {'id': 's4a3'}
# title {}
# p {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# italic {}
# p {}
# sec {'id': 's4a4'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Spanopoulou1'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Eastman2'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Rodgers1'}
# sec {'id': 's4a5'}
# title {}
# p {}
# italic {}
# italic {}
# xref {'ref-type': 'supplementary-material', 'rid': 'st002'}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Fugmann3'}
# sec {'id': 's4a6'}
# title {}
# p {}
# xref {'ref-type': 'bibr', 'rid': 'pbio-0000001-Cowell1'}
# xref {'ref-type': 'supplementary-material', 'rid': 'sd001'}
# sec {'id': 's5'}
# title {}
# supplementary-material {'id': 'sd001', 'mimetype': 'application/msword', 'position': 'anchor', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.sd001', '{http://www.w3.org/1999/xlink}type': 'simple'}
# label {}
# caption {}
# title {}
# p {}
# supplementary-material {'id': 'st001', 'mimetype': 'application/msword', 'position': 'anchor', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.st001', '{http://www.w3.org/1999/xlink}type': 'simple'}
# label {}
# caption {}
# title {}
# p {}
# supplementary-material {'id': 'st002', 'mimetype': 'application/msword', 'position': 'anchor', '{http://www.w3.org/1999/xlink}href': 'info:doi/10.1371/journal.pbio.0000001.st002', '{http://www.w3.org/1999/xlink}type': 'simple'}
# label {}
# caption {}
# title {}
# p {}
# back {}
# ack {}
# p {}
# ref-list {}
# title {}
# ref {'id': 'pbio-0000001-Akamatsu1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Akira1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Argast1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# italic {}
# italic {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Bassing1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Connor1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# etal {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Cowell1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Cowell2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Difilippantonio1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Eastman1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# italic {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Eastman2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Fanning1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Feng1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# italic {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Fugmann1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Fugmann2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Fugmann3'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Gorin1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Hesse1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Hesse2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Hesslein1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Hiom1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Hiom2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Jones1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Jung1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# etal {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Jurica1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# italic {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Larijani1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Leu1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Livak1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Livak2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Mo1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# italic {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Mundy1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Nadel1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# italic {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Nagawa1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# etal {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Ramsden1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Ramsden2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Rodgers1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# etal {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Roman1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Roth1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Spanopoulou1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# etal {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Steen1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Suzuki1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# sub {}
# sub {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Swanson1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Swanson2'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Swanson3'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Tonegawa1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Travers1'}
# label {}
# nlm-citation {'publication-type': 'book', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# year {}
# page-count {'count': '180'}
# ref {'id': 'pbio-0000001-Tsai1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-Wei1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# ref {'id': 'pbio-0000001-West1'}
# label {}
# nlm-citation {'publication-type': 'journal', '{http://www.w3.org/1999/xlink}type': 'simple'}
# person-group {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# name {'name-style': 'western'}
# surname {}
# given-names {}
# article-title {}
# source {}
# year {}
# volume {}
# fpage {}
# lpage {}
# glossary {}
# title {}
# def-list {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}
# def-item {}
# term {}
# def {}
# p {}

# %% [markdown]
# ### Author Names:

# %%
for elem in tree.iter(tag='contrib'):
    for i in elem.iter(tag='surname'):
        print (i.tag, i.attrib,i.text)
    for i in elem.iter(tag='given-names'):
        print (i.tag, i.attrib,i.text)
# Out:
# surname {} Lee
# given-names {} Alfred Ian
# surname {} Fugmann
# given-names {} Sebastian D
# surname {} Cowell
# given-names {} Lindsay G
# surname {} Ptaszek
# given-names {} Leon M
# surname {} Kelsoe
# given-names {} Garnett
# surname {} Schatz
# given-names {} David G
# surname {} Shizuo Akira

# %% [markdown]
# ### Subjects:

# %%
for subject in root.iter('subject'):
    print(subject.text)
# Out:
# Research Article
# Cell Biology
# Immunology
# Molecular Biology
# Mus (mouse)
# Homo (human)

# %% [markdown]
# ### Article Title and Alternative Titles:

# %%
for a in root.iter('article-meta'):
    for elem in a.iter('article-title'):
        print(elem.text)
    for elem in a.iter('alt-title'):
        print(elem.text)
# Out:
# A Functional Analysis of the Spacer of V(D)J Recombination Signal Sequences
# V(D)J Recombination and the Evolution of the Adaptive Immune System
# Functional Analysis of RSS Spacers
# Functional Analysis of RSS Spacers
# During lymphocyte development, V(D)J recombination assembles antigen receptor genes from component V, D, and J gene segments. These gene segments are flanked by a recombination signal sequence (RSS), which serves as the binding site for the recombination machinery. The murine Jβ2.6 gene segment is a recombinationally inactive pseudogene, but examination of its RSS reveals no obvious reason for its failure to recombine. Mutagenesis of the Jβ2.6 RSS demonstrates that the sequences of the heptamer, nonamer, and spacer are all important. Strikingly, changes solely in the spacer sequence can result in dramatic differences in the level of recombination. The subsequent analysis of a library of more than 4,000 spacer variants revealed that spacer residues of particular functional importance are correlated with their degree of conservation. Biochemical assays indicate distinct cooperation between the spacer and heptamer/nonamer along each step of the reaction pathway. The results suggest that the spacer serves not only to ensure the appropriate distance between the heptamer and nonamer but also regulates RSS activity by providing additional RAG:RSS interaction surfaces. We conclude that while RSSs are defined by a “digital” requirement for absolutely conserved nucleotides, the quality of RSS function is determined in an “analog” manner by numerous complex interactions between the RAG proteins and the less-well conserved nucleotides in the heptamer, the nonamer, and, importantly, the spacer. Those modulatory effects are accurately predicted by a new computational algorithm for “RSS information content.” The interplay between such binary and multiplicative modes of interactions provides a general model for analyzing protein–DNA interactions in various biological systems.
# Spacers not only ensure that the distance between the nonamer and heptamer is correct but they also regulate recombination activity by providing protein-binding sites along the DNA sequences that affect recombination.

# %% [markdown]
# ### Abstract:

# %%
for a in root.iter('article-meta'):
    for elem in a.iter('abstract'):    
        for b in elem.iter('p'):
            print(b.text)
# Out:
# During lymphocyte development, V(D)J recombination assembles antigen receptor genes from component V, D, and J gene segments. These gene segments are flanked by a recombination signal sequence (RSS), which serves as the binding site for the recombination machinery. The murine Jβ2.6 gene segment is a recombinationally inactive pseudogene, but examination of its RSS reveals no obvious reason for its failure to recombine. Mutagenesis of the Jβ2.6 RSS demonstrates that the sequences of the heptamer, nonamer, and spacer are all important. Strikingly, changes solely in the spacer sequence can result in dramatic differences in the level of recombination. The subsequent analysis of a library of more than 4,000 spacer variants revealed that spacer residues of particular functional importance are correlated with their degree of conservation. Biochemical assays indicate distinct cooperation between the spacer and heptamer/nonamer along each step of the reaction pathway. The results suggest that the spacer serves not only to ensure the appropriate distance between the heptamer and nonamer but also regulates RSS activity by providing additional RAG:RSS interaction surfaces. We conclude that while RSSs are defined by a “digital” requirement for absolutely conserved nucleotides, the quality of RSS function is determined in an “analog” manner by numerous complex interactions between the RAG proteins and the less-well conserved nucleotides in the heptamer, the nonamer, and, importantly, the spacer. Those modulatory effects are accurately predicted by a new computational algorithm for “RSS information content.” The interplay between such binary and multiplicative modes of interactions provides a general model for analyzing protein–DNA interactions in various biological systems.
# Spacers not only ensure that the distance between the nonamer and heptamer is correct but they also regulate recombination activity by providing protein-binding sites along the DNA sequences that affect recombination.
